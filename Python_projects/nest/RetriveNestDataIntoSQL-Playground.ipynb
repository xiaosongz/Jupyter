# %%
import nest
import os
import json

# %%
import urllib
import urllib2
import sys

from optparse import OptionParser

try:
   import json
except ImportError:
   try:
       import simplejson as json
   except ImportError:
       print "No json library available. I recommend installing either python-json"
       print "or simpejson."
       sys.exit(-1)

class Nest:
    def __init__(self, username, password, serial=None, index=0, units="F"):
        self.username = username
        self.password = password
        self.serial = serial
        self.units = units
        self.index = index

    def loads(self, res):
        if hasattr(json, "loads"):
            res = json.loads(res)
        else:
            res = json.read(res)
        return res

    def login(self):
        data = urllib.urlencode({"username": self.username, "password": self.password})

        req = urllib2.Request("https://home.nest.com/user/login",
                              data,
                              {"user-agent":"Nest/1.1.0.10 CFNetwork/548.0.4"})

        res = urllib2.urlopen(req).read()

        res = self.loads(res)

        self.transport_url = res["urls"]["transport_url"]
        self.access_token = res["access_token"]
        self.userid = res["userid"]

    def get_status(self):
        req = urllib2.Request(self.transport_url + "/v2/mobile/user." + self.userid,
                              headers={"user-agent":"Nest/1.1.0.10 CFNetwork/548.0.4",
                                       "Authorization":"Basic " + self.access_token,
                                       "X-nl-user-id": self.userid,
                                       "X-nl-protocol-version": "1"})

        res = urllib2.urlopen(req).read()

        res = self.loads(res)

        self.structure_id = res["structure"].keys()[0]

        if (self.serial is None):
            self.device_id = res["structure"][self.structure_id]["devices"][self.index]
            self.serial = self.device_id.split(".")[1]

        self.status = res

        #print "res.keys", res.keys()
        #print "res[structure][structure_id].keys", res["structure"][self.structure_id].keys()
        #print "res[device].keys", res["device"].keys()
        #print "res[device][serial].keys", res["device"][self.serial].keys()
        #print "res[shared][serial].keys", res["shared"][self.serial].keys()

    def temp_in(self, temp):
        if (self.units == "F"):
            return (temp - 32.0) / 1.8
        else:
            return temp

    def temp_out(self, temp):
        if (self.units == "F"):
            return temp*1.8 + 32.0
        else:
            return temp

    def show_status(self):
        shared = self.status["shared"][self.serial]
        device = self.status["device"][self.serial]

        allvars = shared
        allvars.update(device)

        for k in sorted(allvars.keys()):
             print k + "."*(32-len(k)) + ":", allvars[k]

    def show_curtemp(self):
        temp = self.status["shared"][self.serial]["current_temperature"]
        temp = self.temp_out(temp)

        print "%0.1f" % temp

    def set_temperature(self, temp):
        temp = self.temp_in(temp)

        data = '{"target_change_pending":true,"target_temperature":' + '%0.1f' % temp + '}'
        req = urllib2.Request(self.transport_url + "/v2/put/shared." + self.serial,
                              data,
                              {"user-agent":"Nest/1.1.0.10 CFNetwork/548.0.4",
                               "Authorization":"Basic " + self.access_token,
                               "X-nl-protocol-version": "1"})

        res = urllib2.urlopen(req).read()

        print res

    def set_fan(self, state):
        data = '{"fan_mode":"' + str(state) + '"}'
        req = urllib2.Request(self.transport_url + "/v2/put/device." + self.serial,
                              data,
                              {"user-agent":"Nest/1.1.0.10 CFNetwork/548.0.4",
                               "Authorization":"Basic " + self.access_token,
                               "X-nl-protocol-version": "1"})

        res = urllib2.urlopen(req).read()

        print res

def create_parser():
   parser = OptionParser(usage="nest [options] command [command_options] [command_args]",
        description="Commands: fan temp",
        version="unknown")

   parser.add_option("-u", "--user", dest="user",
                     help="username for nest.com", metavar="USER", default=None)

   parser.add_option("-p", "--password", dest="password",
                     help="password for nest.com", metavar="PASSWORD", default=None)

   parser.add_option("-c", "--celsius", dest="celsius", action="store_true", default=False,
                     help="use celsius instead of farenheit")

   parser.add_option("-s", "--serial", dest="serial", default=None,
                     help="optional, specify serial number of nest thermostat to talk to")

   parser.add_option("-i", "--index", dest="index", default=0, type="int",
                     help="optional, specify index number of nest to talk to")


   return parser

def help():
    print "syntax: nest [options] command [command_args]"
    print "options:"
    print "   --user <username>      ... username on nest.com"
    print "   --password <password>  ... password on nest.com"
    print "   --celsius              ... use celsius (the default is farenheit)"
    print "   --serial <number>      ... optional, specify serial number of nest to use"
    print "   --index <number>       ... optional, 0-based index of nest"
    print "                                (use --serial or --index, but not both)"
    print
    print "commands: temp, fan, show, curtemp, curhumid"
    print "    temp <temperature>    ... set target temperature"
    print "    fan [auto|on]         ... set fan state"
    print "    show                  ... show everything"
    print "    curtemp               ... print current temperature"
    print "    curhumid              ... print current humidity"
    print
    print "examples:"
    print "    nest.py --user joe@user.com --password swordfish temp 73"
    print "    nest.py --user joe@user.com --password swordfish fan auto"

def main():
    parser = create_parser()
    (opts, args) = parser.parse_args()

    if (len(args)==0) or (args[0]=="help"):
        help()
        sys.exit(-1)

    if (not opts.user) or (not opts.password):
        print "how about specifying a --user and --password option next time?"
        sys.exit(-1)

    if opts.celsius:
        units = "C"
    else:
        units = "F"

    n = Nest(opts.user, opts.password, opts.serial, opts.index, units=units)
    n.login()
    n.get_status()

    cmd = args[0]

    if (cmd == "temp"):
        if len(args)<2:
            print "please specify a temperature"
            sys.exit(-1)
        n.set_temperature(int(args[1]))
    elif (cmd == "fan"):
        if len(args)<2:
            print "please specify a fan state of 'on' or 'auto'"
            sys.exit(-1)
        n.set_fan(args[1])
    elif (cmd == "show"):
        n.show_status()
        return res
    elif (cmd == "curtemp"):
        n.show_curtemp()
    elif (cmd == "curhumid"):
        print n.status["device"][n.serial]["current_humidity"]
    else:
        print "misunderstood command:", cmd
        print "do 'nest.py help' for help"

# if __name__=="__main__":
#     main()

# %%
username = 'zorroxinxsindi@gmail.com'
password = 'gdJide141@'
n = Nest(username, password, units = "F")
n.login()
n.get_status()
n.show_status()
# Out:
# $timestamp......................: 1481648378169
# $version........................: -7418
# alt_heat_delivery...............: forced-air
# alt_heat_source.................: gas
# alt_heat_x2_delivery............: forced-air
# alt_heat_x2_source..............: gas
# auto_away.......................: 0
# auto_away_enable................: True
# auto_away_learning..............: ready
# auto_away_reset.................: False
# auto_dehum_enabled..............: True
# auto_dehum_state................: False
# aux_heat_delivery...............: forced-air
# aux_heat_source.................: electric
# aux_lockout_leaf................: 10.0
# available_locales...............: en_US,fr_CA,es_US,en_GB,fr_FR,nl_NL
# away_temperature_high...........: 30.278
# away_temperature_high_adjusted..: 30.278
# away_temperature_high_enabled...: True
# away_temperature_low............: 10.39597
# away_temperature_low_adjusted...: 10.39597
# away_temperature_low_enabled....: True
# backplate_bsl_info..............: BSL
# backplate_bsl_version...........: 3.1
# backplate_model.................: Backplate-5.3
# backplate_mono_info.............: TFE (BP_D3) 1.2.9 (root@sticks.pao.corp.google.com) 2016-08-17 12:36:42
# backplate_mono_version..........: 1.2.9
# backplate_serial_number.........: 09DA01AC44150M4L
# battery_level...................: 3.904
# can_cool........................: True
# can_heat........................: True
# capability_level................: 5.6
# click_sound.....................: on
# compressor_lockout_enabled......: False
# compressor_lockout_leaf.........: -17.79999
# compressor_lockout_timeout......: 0
# cooling_delivery................: unknown
# cooling_source..................: electric
# cooling_x2_delivery.............: unknown
# cooling_x2_source...............: electric
# cooling_x3_delivery.............: unknown
# cooling_x3_source...............: electric
# country_code....................: US
# creation_time...................: 1452649087971
# current_humidity................: 34
# current_schedule_mode...........: HEAT
# current_temperature.............: 23.73999
# current_version.................: 5.6-7
# dehumidifier_orientation_selected: unknown
# dehumidifier_state..............: False
# dehumidifier_type...............: unknown
# demand_charge_icon..............: False
# device_locale...................: en_US
# dual_fuel_breakpoint............: -1.0
# dual_fuel_breakpoint_override...: none
# eco.............................: {u'touched_by': 1, u'mode': u'schedule', u'mode_update_timestamp': 1481640199}
# eco_onboarding_needed...........: True
# emer_heat_delivery..............: forced-air
# emer_heat_enable................: False
# emer_heat_source................: electric
# equipment_type..................: electric
# error_code......................:
# fan_capabilities................: stage1
# fan_control_state...............: False
# fan_cooling_enabled.............: True
# fan_cooling_readiness...........: ready
# fan_cooling_state...............: False
# fan_current_speed...............: off
# fan_duty_cycle..................: 900
# fan_duty_end_time...............: 25200
# fan_duty_start_time.............: 0
# fan_heat_cool_speed.............: auto
# fan_mode........................: auto
# fan_schedule_speed..............: stage1
# fan_timer_duration..............: 1800
# fan_timer_speed.................: stage1
# fan_timer_timeout...............: 0
# farsight_screen.................: target_temp
# filter_changed_date.............: 1479168000
# filter_changed_set_date.........: 1478853676
# filter_reminder_enabled.........: True
# filter_reminder_level...........: 0
# forced_air......................: True
# gear_threshold_high.............: 0.0
# gear_threshold_low..............: 0.0
# has_air_filter..................: True
# has_alt_heat....................: False
# has_aux_heat....................: False
# has_dehumidifier................: False
# has_dual_fuel...................: False
# has_emer_heat...................: False
# has_fan.........................: True
# has_fossil_fuel.................: True
# has_heat_pump...................: False
# has_hot_water_control...........: False
# has_hot_water_temperature.......: False
# has_humidifier..................: False
# has_x2_alt_heat.................: False
# has_x2_cool.....................: False
# has_x2_heat.....................: False
# has_x3_cool.....................: False
# has_x3_heat.....................: False
# heat_link_connection............: 0
# heat_pump_aux_threshold.........: 10.0
# heat_pump_aux_threshold_enabled.: True
# heat_pump_comp_threshold........: -31.5
# heat_pump_comp_threshold_enabled: False
# heat_x2_delivery................: forced-air
# heat_x2_source..................: gas
# heat_x3_delivery................: forced-air
# heat_x3_source..................: gas
# heater_delivery.................: forced-air
# heater_source...................: gas
# heatpump_ready..................: False
# heatpump_savings................: off
# heatpump_setback_active.........: False
# home_away_input.................: True
# hot_water_active................: False
# hot_water_away_active...........: False
# hot_water_away_enabled..........: True
# hot_water_boiling_state.........: True
# humidifier_state................: False
# humidifier_type.................: unknown
# humidity_control_lockout_enabled: False
# humidity_control_lockout_end_time: 0
# humidity_control_lockout_start_time: 0
# hvac_ac_state...................: False
# hvac_alt_heat_state.............: False
# hvac_alt_heat_x2_state..........: False
# hvac_aux_heater_state...........: False
# hvac_cool_x2_state..............: False
# hvac_cool_x3_state..............: False
# hvac_emer_heat_state............: False
# hvac_fan_state..................: False
# hvac_heat_x2_state..............: False
# hvac_heat_x3_state..............: False
# hvac_heater_state...............: False
# hvac_pins.......................: W1,Y1,Rh,G
# hvac_safety_shutoff_active......: False
# hvac_smoke_safety_shutoff_active: False
# hvac_staging_ignore.............: False
# hvac_wires......................: Heat,Cool,Fan,Rh
# is_furnace_shutdown.............: False
# last_software_update_utc_secs...: 1477962549
# leaf............................: False
# leaf_away_high..................: 28.87999
# leaf_away_low...................: 20.08333
# leaf_schedule_delta.............: 1.10999
# leaf_threshold_cool.............: 0.0
# leaf_threshold_heat.............: 22.23
# learning_days_completed_cool....: 105
# learning_days_completed_heat....: 122
# learning_days_completed_range...: 72
# learning_mode...................: True
# learning_state..................: slow
# learning_time...................: 22
# local_ip........................: 10.0.0.106
# logging_priority................: informational
# lower_safety_temp...............: 7.22221
# lower_safety_temp_enabled.......: True
# mac_address.....................: 18b43071fa3a
# maint_band_lower................: 0.39
# maint_band_upper................: 0.39
# max_nighttime_preconditioning_seconds: 18000
# model_version...................: Display-3.4
# name............................: Oasis
# nlclient_state..................:
# note_codes......................: []
# ob_orientation..................: O
# ob_persistence..................: True
# oob_interview_completed.........: True
# oob_startup_completed...........: True
# oob_summary_completed...........: True
# oob_temp_completed..............: True
# oob_test_completed..............: True
# oob_where_completed.............: True
# oob_wifi_completed..............: True
# oob_wires_completed.............: True
# pin_c_description...............: none
# pin_g_description...............: fan
# pin_ob_description..............: none
# pin_rc_description..............: none
# pin_rh_description..............: power
# pin_star_description............: none
# pin_w1_description..............: heat
# pin_w2aux_description...........: none
# pin_y1_description..............: cool
# pin_y2_description..............: none
# postal_code.....................: 43615
# preconditioning_active..........: False
# preconditioning_enabled.........: True
# preconditioning_ready...........: True
# pro_id..........................: HP8A8A
# radiant_control_enabled.........: False
# range_enable....................: True
# rssi............................: 73.0
# safety_state....................: none
# safety_state_time...............: 1479600550
# safety_temp_activating_hvac.....: False
# schedule_learning_reset.........: False
# schedules.......................: []
# serial_number...................: 09AA01AC46150F2G
# should_wake_on_approach.........: True
# smoke_shutoff_supported.........: True
# star_type.......................: unknown
# sunlight_correction_active......: False
# sunlight_correction_enabled.....: False
# sunlight_correction_ready.......: False
# switch_system_off...............: False
# target_change_pending...........: False
# target_humidity.................: 35.0
# target_humidity_enabled.........: False
# target_temperature..............: 23.5
# target_temperature_high.........: 24.0
# target_temperature_low..........: 20.0
# target_temperature_type.........: heat
# target_time_confidence..........: 0.0
# temperature_lock................: False
# temperature_lock_high_temp......: 22.222
# temperature_lock_low_temp.......: 20.0
# temperature_lock_pin_hash.......:
# temperature_scale...............: F
# time_to_target..................: 0
# time_to_target_training.........: ready
# tou_icon........................: False
# touched_by......................: {}
# type............................: TBD
# upper_safety_temp...............: 35.062
# upper_safety_temp_enabled.......: True
# user_brightness.................: auto
# where_id........................: 00000000-0000-0000-0000-00010000000c
# y2_type.........................: unknown

# %%
n.status
# Out:
# {u'buckets': {u'2925484': {u'$timestamp': 1480498030799,
#    u'$version': -22704,
#    u'buckets': [u'user.2925484',
#     u'user_alert_dialog.2925484',
#     u'message_center.2925484',
#     u'user_settings.2925484',
#     u'buckets.2925484',
#     u'device.09AA01AC46150F2G',
#     u'demand_response.09AA01AC46150F2G',
#     u'device_alert_dialog.09AA01AC46150F2G',
#     u'link.09AA01AC46150F2G',
#     u'message.09AA01AC46150F2G',
#     u'metadata.09AA01AC46150F2G',
#     u'schedule.09AA01AC46150F2G',
#     u'shared.09AA01AC46150F2G',
#     u'track.09AA01AC46150F2G',
#     u'tuneups.09AA01AC46150F2G',
#     u'energy_latest.09AA01AC46150F2G',
#     u'energy_weekly.09AA01AC46150F2G',
#     u'tou.09AA01AC46150F2G',
#     u'demand_charge.09AA01AC46150F2G',
#     u'structure.37051b70-b997-11e5-9399-22000b6d823e',
#     u'where.37051b70-b997-11e5-9399-22000b6d823e',
#     u'utility.37051b70-b997-11e5-9399-22000b6d823e',
#     u'structure_history.37051b70-b997-11e5-9399-22000b6d823e',
#     u'trip.37051b70-b997-11e5-9399-22000b6d823e',
#     u'structure_metadata.37051b70-b997-11e5-9399-22000b6d823e',
#     u'safety.37051b70-b997-11e5-9399-22000b6d823e',
#     u'safety_summary.37051b70-b997-11e5-9399-22000b6d823e',
#     u'geofence_info.37051b70-b997-11e5-9399-22000b6d823e']}},
#  u'demand_charge': {u'09AA01AC46150F2G': {u'$timestamp': 1, u'$version': -1}},
#  u'demand_response': {u'09AA01AC46150F2G': {u'$timestamp': 1,
#    u'$version': -1}},
#  u'device': {u'09AA01AC46150F2G': {u'$timestamp': 1481600788882,
#    u'$version': 3965,
#    u'alt_heat_delivery': u'forced-air',
#    u'alt_heat_source': u'gas',
#    u'alt_heat_x2_delivery': u'forced-air',
#    u'alt_heat_x2_source': u'gas',
#    u'auto_away_enable': True,
#    u'auto_away_reset': False,
#    u'auto_dehum_enabled': True,
#    u'auto_dehum_state': False,
#    u'aux_heat_delivery': u'forced-air',
#    u'aux_heat_source': u'electric',
#    u'aux_lockout_leaf': 10.0,
#    u'available_locales': u'en_US,fr_CA,es_US,en_GB,fr_FR,nl_NL',
#    u'away_temperature_high': 30.278,
#    u'away_temperature_high_adjusted': 30.278,
#    u'away_temperature_high_enabled': True,
#    u'away_temperature_low': 10.39597,
#    u'away_temperature_low_adjusted': 10.39597,
#    u'away_temperature_low_enabled': True,
#    u'backplate_bsl_info': u'BSL',
#    u'backplate_bsl_version': u'3.1',
#    u'backplate_model': u'Backplate-5.3',
#    u'backplate_mono_info': u'TFE (BP_D3) 1.2.9 (root@sticks.pao.corp.google.com) 2016-08-17 12:36:42',
#    u'backplate_mono_version': u'1.2.9',
#    u'backplate_serial_number': u'09DA01AC44150M4L',
#    u'battery_level': 3.871,
#    u'capability_level': 5.6,
#    u'click_sound': u'on',
#    u'compressor_lockout_leaf': -17.79999,
#    u'cooling_delivery': u'unknown',
#    u'cooling_source': u'electric',
#    u'cooling_x2_delivery': u'unknown',
#    u'cooling_x2_source': u'electric',
#    u'cooling_x3_delivery': u'unknown',
#    u'cooling_x3_source': u'electric',
#    u'country_code': u'US',
#    u'creation_time': 1452649087971,
#    u'current_humidity': 42,
#    u'current_schedule_mode': u'HEAT',
#    u'current_version': u'5.6-7',
#    u'dehumidifier_orientation_selected': u'unknown',
#    u'dehumidifier_state': False,
#    u'dehumidifier_type': u'unknown',
#    u'demand_charge_icon': False,
#    u'device_locale': u'en_US',
#    u'dual_fuel_breakpoint': -1.0,
#    u'dual_fuel_breakpoint_override': u'none',
#    u'eco': {u'mode': u'schedule',
#     u'mode_update_timestamp': 1481409207,
#     u'touched_by': 6},
#    u'eco_onboarding_needed': True,
#    u'emer_heat_delivery': u'forced-air',
#    u'emer_heat_enable': False,
#    u'emer_heat_source': u'electric',
#    u'equipment_type': u'electric',
#    u'error_code': u'',
#    u'fan_capabilities': u'stage1',
#    u'fan_control_state': False,
#    u'fan_cooling_enabled': True,
#    u'fan_cooling_readiness': u'ready',
#    u'fan_cooling_state': False,
#    u'fan_current_speed': u'off',
#    u'fan_duty_cycle': 900,
#    u'fan_duty_end_time': 25200,
#    u'fan_duty_start_time': 0,
#    u'fan_heat_cool_speed': u'auto',
#    u'fan_mode': u'auto',
#    u'fan_schedule_speed': u'stage1',
#    u'fan_timer_duration': 1800,
#    u'fan_timer_speed': u'stage1',
#    u'fan_timer_timeout': 0,
#    u'farsight_screen': u'target_temp',
#    u'filter_changed_date': 1479168000,
#    u'filter_changed_set_date': 1478853676,
#    u'filter_reminder_enabled': True,
#    u'filter_reminder_level': 0,
#    u'forced_air': True,
#    u'gear_threshold_high': 0.0,
#    u'gear_threshold_low': 0.0,
#    u'has_air_filter': True,
#    u'has_alt_heat': False,
#    u'has_aux_heat': False,
#    u'has_dehumidifier': False,
#    u'has_dual_fuel': False,
#    u'has_emer_heat': False,
#    u'has_fan': True,
#    u'has_fossil_fuel': True,
#    u'has_heat_pump': False,
#    u'has_hot_water_control': False,
#    u'has_hot_water_temperature': False,
#    u'has_humidifier': False,
#    u'has_x2_alt_heat': False,
#    u'has_x2_cool': False,
#    u'has_x2_heat': False,
#    u'has_x3_cool': False,
#    u'has_x3_heat': False,
#    u'heat_link_connection': 0,
#    u'heat_pump_aux_threshold': 10.0,
#    u'heat_pump_aux_threshold_enabled': True,
#    u'heat_pump_comp_threshold': -31.5,
#    u'heat_pump_comp_threshold_enabled': False,
#    u'heat_x2_delivery': u'forced-air',
#    u'heat_x2_source': u'gas',
#    u'heat_x3_delivery': u'forced-air',
#    u'heat_x3_source': u'gas',
#    u'heater_delivery': u'forced-air',
#    u'heater_source': u'gas',
#    u'heatpump_ready': False,
#    u'heatpump_savings': u'off',
#    u'heatpump_setback_active': False,
#    u'home_away_input': True,
#    u'hot_water_active': False,
#    u'hot_water_away_active': False,
#    u'hot_water_away_enabled': True,
#    u'hot_water_boiling_state': True,
#    u'humidifier_state': False,
#    u'humidifier_type': u'unknown',
#    u'humidity_control_lockout_enabled': False,
#    u'humidity_control_lockout_end_time': 0,
#    u'humidity_control_lockout_start_time': 0,
#    u'hvac_pins': u'W1,Y1,Rh,G',
#    u'hvac_safety_shutoff_active': False,
#    u'hvac_smoke_safety_shutoff_active': False,
#    u'hvac_staging_ignore': False,
#    u'hvac_wires': u'Heat,Cool,Fan,Rh',
#    u'is_furnace_shutdown': False,
#    u'last_software_update_utc_secs': 1477962549,
#    u'leaf': False,
#    u'leaf_away_high': 28.87999,
#    u'leaf_away_low': 20.08333,
#    u'leaf_schedule_delta': 1.10999,
#    u'leaf_threshold_cool': 0.0,
#    u'leaf_threshold_heat': 22.23,
#    u'learning_days_completed_cool': 105,
#    u'learning_days_completed_heat': 122,
#    u'learning_days_completed_range': 72,
#    u'learning_mode': True,
#    u'learning_state': u'slow',
#    u'learning_time': 22,
#    u'local_ip': u'10.0.0.106',
#    u'logging_priority': u'informational',
#    u'lower_safety_temp': 7.22221,
#    u'lower_safety_temp_enabled': True,
#    u'mac_address': u'18b43071fa3a',
#    u'maint_band_lower': 0.39,
#    u'maint_band_upper': 0.39,
#    u'max_nighttime_preconditioning_seconds': 18000,
#    u'model_version': u'Display-3.4',
#    u'nlclient_state': u'',
#    u'note_codes': [],
#    u'ob_orientation': u'O',
#    u'ob_persistence': True,
#    u'oob_interview_completed': True,
#    u'oob_startup_completed': True,
#    u'oob_summary_completed': True,
#    u'oob_temp_completed': True,
#    u'oob_test_completed': True,
#    u'oob_where_completed': True,
#    u'oob_wifi_completed': True,
#    u'oob_wires_completed': True,
#    u'pin_c_description': u'none',
#    u'pin_g_description': u'fan',
#    u'pin_ob_description': u'none',
#    u'pin_rc_description': u'none',
#    u'pin_rh_description': u'power',
#    u'pin_star_description': u'none',
#    u'pin_w1_description': u'heat',
#    u'pin_w2aux_description': u'none',
#    u'pin_y1_description': u'cool',
#    u'pin_y2_description': u'none',
#    u'postal_code': u'43615',
#    u'preconditioning_active': False,
#    u'preconditioning_enabled': True,
#    u'preconditioning_ready': True,
#    u'pro_id': u'HP8A8A',
#    u'radiant_control_enabled': False,
#    u'range_enable': True,
#    u'rssi': 81.0,
#    u'safety_state': u'none',
#    u'safety_state_time': 1479600550,
#    u'safety_temp_activating_hvac': False,
#    u'schedule_learning_reset': False,
#    u'schedules': [],
#    u'serial_number': u'09AA01AC46150F2G',
#    u'should_wake_on_approach': True,
#    u'smoke_shutoff_supported': True,
#    u'star_type': u'unknown',
#    u'sunlight_correction_active': False,
#    u'sunlight_correction_enabled': False,
#    u'sunlight_correction_ready': False,
#    u'switch_system_off': False,
#    u'target_humidity': 35.0,
#    u'target_humidity_enabled': False,
#    u'target_time_confidence': 0.0,
#    u'temperature_lock': False,
#    u'temperature_lock_high_temp': 22.222,
#    u'temperature_lock_low_temp': 20.0,
#    u'temperature_lock_pin_hash': u'',
#    u'temperature_scale': u'F',
#    u'time_to_target': 0,
#    u'time_to_target_training': u'ready',
#    u'tou_icon': False,
#    u'touched_by': {},
#    u'type': u'TBD',
#    u'upper_safety_temp': 35.062,
#    u'upper_safety_temp_enabled': True,
#    u'user_brightness': u'auto',
#    u'where_id': u'00000000-0000-0000-0000-00010000000c',
#    u'y2_type': u'unknown'}},
#  u'device_alert_dialog': {u'09AA01AC46150F2G': {u'$timestamp': 1452649572044,
#    u'$version': -26252,
#    u'dialog_data': u'',
#    u'dialog_id': u'confirm-pairing'}},
#  u'geofence_info': {u'37051b70-b997-11e5-9399-22000b6d823e': {u'$timestamp': 1481587521391,
#    u'$version': -27010,
#    u'combined_presence': {u'presence': 0,
#     u'presence_evaluation_timestamp': 1481328968000},
#    u'device_events': [{u'device_id': u'86089634-92B5-4EE8-AEE5-0D9891073970',
#      u'events': [{u'fence_id': u'37051b70-b997-11e5-9399-22000b6d823e:rzCzX1Zc',
#        u'state': 0,
#        u'time_of_state_transition': 1481328968000,
#        u'time_state_reported': 1481328968000,
#        u'user_id': u'2925484'}],
#      u'is_attached_to_occupancy': True,
#      u'is_primary_device': True}],
#    u'fences': [{u'direction': [0, 1],
#      u'fence_id': u'37051b70-b997-11e5-9399-22000b6d823e:rzCzX1Zc',
#      u'latitude': 41.64928247854032,
#      u'longitude': -83.65790577110907,
#      u'radius': 200}]}},
#  u'link': {u'09AA01AC46150F2G': {u'$timestamp': 1452649572044,
#    u'$version': -2397,
#    u'structure': u'structure.37051b70-b997-11e5-9399-22000b6d823e'}},
#  u'message': {u'09AA01AC46150F2G': {u'$timestamp': 1477199673237,
#    u'$version': 26113}},
#  u'message_center': {u'2925484': {u'$timestamp': 1481564517253,
#    u'$version': 1537,
#    u'messages': [{u'dismissed': True,
#      u'id': u'6d9fd500-c065-11e6-8826-22000acb84ae',
#      u'key': u'mobile_device_health_check_fail',
#      u'parameters': [u'zorroxinxsindi@gmail.com'],
#      u'priority': 2,
#      u'read': True,
#      u'thread_id': 0,
#      u'timestamp': 1481546163}]}},
#  u'metadata': {u'09AA01AC46150F2G': {u'$timestamp': 1356998400000,
#    u'$version': -1,
#    u'last_connection': 1356998400000,
#    u'last_ip': u'127.0.0.1'}},
#  u'safety': {u'37051b70-b997-11e5-9399-22000b6d823e': {u'$timestamp': 1452649481991,
#    u'$version': -7879,
#    u'audio_self_test_participants': []}},
#  u'safety_summary': {u'37051b70-b997-11e5-9399-22000b6d823e': {u'$timestamp': 1452649481991,
#    u'$version': -25109}},
#  u'schedule': {u'09AA01AC46150F2G': {u'$timestamp': 1481521258607,
#    u'$version': -18345,
#    u'days': {u'0': {u'0': {u'entry_type': u'continuation',
#       u'temp': 23.5,
#       u'time': 0,
#       u'touched_at': 1481474493,
#       u'touched_by': 1,
#       u'touched_tzo': -18000,
#       u'type': u'HEAT'},
#      u'1': {u'entry_type': u'setpoint',
#       u'temp': 20.08333,
#       u'time': 3600,
#       u'touched_at': 1481474474,
#       u'touched_by': 6,
#       u'touched_tzo': -18000,
#       u'touched_user_id': u'user.2925484',
#       u'type': u'HEAT'},
#      u'2': {u'entry_type': u'setpoint',
#       u'temp': 24.23984,
#       u'time': 25200,
#       u'touched_at': 1481474474,
#       u'touched_by': 6,
#       u'touched_tzo': -18000,
#       u'touched_user_id': u'user.2925484',
#       u'type': u'HEAT'},
#      u'3': {u'entry_type': u'setpoint',
#       u'temp': 23.5,
#       u'time': 44100,
#       u'touched_at': 1481474474,
#       u'touched_by': 6,
#       u'touched_tzo': -18000,
#       u'touched_user_id': u'user.2925484',
#       u'type': u'HEAT'}},
#     u'1': {u'0': {u'entry_type': u'continuation',
#       u'temp': 23.5,
#       u'time': 0,
#       u'touched_at': 1481474493,
#       u'touched_by': 1,
#       u'touched_tzo': -18000,
#       u'type': u'HEAT'},
#      u'1': {u'entry_type': u'setpoint',
#       u'temp': 20.08333,
#       u'time': 3600,
#       u'touched_at': 1481474472,
#       u'touched_by': 6,
#       u'touched_tzo': -18000,
#       u'touched_user_id': u'user.2925484',
#       u'type': u'HEAT'},
#      u'2': {u'entry_type': u'setpoint',
#       u'temp': 24.23984,
#       u'time': 25200,
#       u'touched_at': 1481474472,
#       u'touched_by': 6,
#       u'touched_tzo': -18000,
#       u'touched_user_id': u'user.2925484',
#       u'type': u'HEAT'},
#      u'3': {u'entry_type': u'setpoint',
#       u'temp': 23.5,
#       u'time': 44100,
#       u'touched_at': 1481474472,
#       u'touched_by': 6,
#       u'touched_tzo': -18000,
#       u'touched_user_id': u'user.2925484',
#       u'type': u'HEAT'}},
#     u'2': {u'0': {u'entry_type': u'continuation',
#       u'temp': 23.5,
#       u'time': 0,
#       u'touched_at': 1481474493,
#       u'touched_by': 1,
#       u'touched_tzo': -18000,
#       u'type': u'HEAT'},
#      u'1': {u'entry_type': u'setpoint',
#       u'temp': 20.08333,
#       u'time': 3600,
#       u'touched_at': 1481474471,
#       u'touched_by': 6,
#       u'touched_tzo': -18000,
#       u'touched_user_id': u'user.2925484',
#       u'type': u'HEAT'},
#      u'2': {u'entry_type': u'setpoint',
#       u'temp': 24.23984,
#       u'time': 25200,
#       u'touched_at': 1481474471,
#       u'touched_by': 6,
#       u'touched_tzo': -18000,
#       u'touched_user_id': u'user.2925484',
#       u'type': u'HEAT'},
#      u'3': {u'entry_type': u'setpoint',
#       u'temp': 23.5,
#       u'time': 44100,
#       u'touched_at': 1481474471,
#       u'touched_by': 6,
#       u'touched_tzo': -18000,
#       u'touched_user_id': u'user.2925484',
#       u'type': u'HEAT'}},
#     u'3': {u'0': {u'entry_type': u'continuation',
#       u'temp': 23.5,
#       u'time': 0,
#       u'touched_at': 1481474493,
#       u'touched_by': 1,
#       u'touched_tzo': -18000,
#       u'type': u'HEAT'},
#      u'1': {u'entry_type': u'setpoint',
#       u'temp': 20.08333,
#       u'time': 3600,
#       u'touched_at': 1481430340,
#       u'touched_by': 6,
#       u'touched_tzo': -18000,
#       u'touched_user_id': u'user.2925484',
#       u'type': u'HEAT'},
#      u'2': {u'entry_type': u'setpoint',
#       u'temp': 24.23984,
#       u'time': 25200,
#       u'touched_at': 1481474466,
#       u'touched_by': 6,
#       u'touched_tzo': -18000,
#       u'touched_user_id': u'user.2925484',
#       u'type': u'HEAT'},
#      u'3': {u'entry_type': u'setpoint',
#       u'temp': 23.5,
#       u'time': 44100,
#       u'touched_at': 1481430340,
#       u'touched_by': 6,
#       u'touched_tzo': -18000,
#       u'touched_user_id': u'user.2925484',
#       u'type': u'HEAT'}},
#     u'4': {u'0': {u'entry_type': u'continuation',
#       u'temp': 23.5,
#       u'time': 0,
#       u'touched_at': 1481474493,
#       u'touched_by': 1,
#       u'touched_tzo': -18000,
#       u'type': u'HEAT'},
#      u'1': {u'entry_type': u'setpoint',
#       u'temp': 20.08333,
#       u'time': 3600,
#       u'touched_at': 1481474437,
#       u'touched_by': 6,
#       u'touched_tzo': -18000,
#       u'touched_user_id': u'user.2925484',
#       u'type': u'HEAT'},
#      u'2': {u'entry_type': u'setpoint',
#       u'temp': 24.23984,
#       u'time': 33300,
#       u'touched_at': 1481474459,
#       u'touched_by': 6,
#       u'touched_tzo': -18000,
#       u'touched_user_id': u'user.2925484',
#       u'type': u'HEAT'},
#      u'3': {u'entry_type': u'setpoint',
#       u'temp': 23.5,
#       u'time': 44100,
#       u'touched_at': 1481474437,
#       u'touched_by': 6,
#       u'touched_tzo': -18000,
#       u'touched_user_id': u'user.2925484',
#       u'type': u'HEAT'}},
#     u'5': {u'0': {u'entry_type': u'continuation',
#       u'temp': 23.5,
#       u'time': 0,
#       u'touched_at': 1481474493,
#       u'touched_by': 1,
#       u'touched_tzo': -18000,
#       u'type': u'HEAT'},
#      u'1': {u'entry_type': u'setpoint',
#       u'temp': 20.08333,
#       u'time': 3600,
#       u'touched_at': 1481430336,
#       u'touched_by': 6,
#       u'touched_tzo': -18000,
#       u'touched_user_id': u'user.2925484',
#       u'type': u'HEAT'},
#      u'2': {u'entry_type': u'setpoint',
#       u'temp': 24.23984,
#       u'time': 32400,
#       u'touched_at': 1481430336,
#       u'touched_by': 6,
#       u'touched_tzo': -18000,
#       u'touched_user_id': u'user.2925484',
#       u'type': u'HEAT'},
#      u'3': {u'entry_type': u'setpoint',
#       u'temp': 23.5,
#       u'time': 44100,
#       u'touched_at': 1481430336,
#       u'touched_by': 6,
#       u'touched_tzo': -18000,
#       u'touched_user_id': u'user.2925484',
#       u'type': u'HEAT'}},
#     u'6': {u'0': {u'entry_type': u'continuation',
#       u'temp': 23.5,
#       u'time': 0,
#       u'touched_at': 1481474493,
#       u'touched_by': 1,
#       u'touched_tzo': -18000,
#       u'type': u'HEAT'},
#      u'1': {u'entry_type': u'setpoint',
#       u'temp': 20.08333,
#       u'time': 3600,
#       u'touched_at': 1481474435,
#       u'touched_by': 6,
#       u'touched_tzo': -18000,
#       u'touched_user_id': u'user.2925484',
#       u'type': u'HEAT'},
#      u'2': {u'entry_type': u'setpoint',
#       u'temp': 24.23984,
#       u'time': 32400,
#       u'touched_at': 1481474435,
#       u'touched_by': 6,
#       u'touched_tzo': -18000,
#       u'touched_user_id': u'user.2925484',
#       u'type': u'HEAT'},
#      u'3': {u'entry_type': u'setpoint',
#       u'temp': 23.5,
#       u'time': 44100,
#       u'touched_at': 1481474435,
#       u'touched_by': 6,
#       u'touched_tzo': -18000,
#       u'touched_user_id': u'user.2925484',
#       u'type': u'HEAT'}}},
#    u'name': u'Current Schedule',
#    u'schedule_mode': u'HEAT',
#    u'ver': 2}},
#  u'shared': {u'09AA01AC46150F2G': {u'$timestamp': 1481600788882,
#    u'$version': 3965,
#    u'alt_heat_delivery': u'forced-air',
#    u'alt_heat_source': u'gas',
#    u'alt_heat_x2_delivery': u'forced-air',
#    u'alt_heat_x2_source': u'gas',
#    u'auto_away': 0,
#    u'auto_away_enable': True,
#    u'auto_away_learning': u'ready',
#    u'auto_away_reset': False,
#    u'auto_dehum_enabled': True,
#    u'auto_dehum_state': False,
#    u'aux_heat_delivery': u'forced-air',
#    u'aux_heat_source': u'electric',
#    u'aux_lockout_leaf': 10.0,
#    u'available_locales': u'en_US,fr_CA,es_US,en_GB,fr_FR,nl_NL',
#    u'away_temperature_high': 30.278,
#    u'away_temperature_high_adjusted': 30.278,
#    u'away_temperature_high_enabled': True,
#    u'away_temperature_low': 10.39597,
#    u'away_temperature_low_adjusted': 10.39597,
#    u'away_temperature_low_enabled': True,
#    u'backplate_bsl_info': u'BSL',
#    u'backplate_bsl_version': u'3.1',
#    u'backplate_model': u'Backplate-5.3',
#    u'backplate_mono_info': u'TFE (BP_D3) 1.2.9 (root@sticks.pao.corp.google.com) 2016-08-17 12:36:42',
#    u'backplate_mono_version': u'1.2.9',
#    u'backplate_serial_number': u'09DA01AC44150M4L',
#    u'battery_level': 3.871,
#    u'can_cool': True,
#    u'can_heat': True,
#    u'capability_level': 5.6,
#    u'click_sound': u'on',
#    u'compressor_lockout_enabled': False,
#    u'compressor_lockout_leaf': -17.79999,
#    u'compressor_lockout_timeout': 0,
#    u'cooling_delivery': u'unknown',
#    u'cooling_source': u'electric',
#    u'cooling_x2_delivery': u'unknown',
#    u'cooling_x2_source': u'electric',
#    u'cooling_x3_delivery': u'unknown',
#    u'cooling_x3_source': u'electric',
#    u'country_code': u'US',
#    u'creation_time': 1452649087971,
#    u'current_humidity': 42,
#    u'current_schedule_mode': u'HEAT',
#    u'current_temperature': 23.51999,
#    u'current_version': u'5.6-7',
#    u'dehumidifier_orientation_selected': u'unknown',
#    u'dehumidifier_state': False,
#    u'dehumidifier_type': u'unknown',
#    u'demand_charge_icon': False,
#    u'device_locale': u'en_US',
#    u'dual_fuel_breakpoint': -1.0,
#    u'dual_fuel_breakpoint_override': u'none',
#    u'eco': {u'mode': u'schedule',
#     u'mode_update_timestamp': 1481409207,
#     u'touched_by': 6},
#    u'eco_onboarding_needed': True,
#    u'emer_heat_delivery': u'forced-air',
#    u'emer_heat_enable': False,
#    u'emer_heat_source': u'electric',
#    u'equipment_type': u'electric',
#    u'error_code': u'',
#    u'fan_capabilities': u'stage1',
#    u'fan_control_state': False,
#    u'fan_cooling_enabled': True,
#    u'fan_cooling_readiness': u'ready',
#    u'fan_cooling_state': False,
#    u'fan_current_speed': u'off',
#    u'fan_duty_cycle': 900,
#    u'fan_duty_end_time': 25200,
#    u'fan_duty_start_time': 0,
#    u'fan_heat_cool_speed': u'auto',
#    u'fan_mode': u'auto',
#    u'fan_schedule_speed': u'stage1',
#    u'fan_timer_duration': 1800,
#    u'fan_timer_speed': u'stage1',
#    u'fan_timer_timeout': 0,
#    u'farsight_screen': u'target_temp',
#    u'filter_changed_date': 1479168000,
#    u'filter_changed_set_date': 1478853676,
#    u'filter_reminder_enabled': True,
#    u'filter_reminder_level': 0,
#    u'forced_air': True,
#    u'gear_threshold_high': 0.0,
#    u'gear_threshold_low': 0.0,
#    u'has_air_filter': True,
#    u'has_alt_heat': False,
#    u'has_aux_heat': False,
#    u'has_dehumidifier': False,
#    u'has_dual_fuel': False,
#    u'has_emer_heat': False,
#    u'has_fan': True,
#    u'has_fossil_fuel': True,
#    u'has_heat_pump': False,
#    u'has_hot_water_control': False,
#    u'has_hot_water_temperature': False,
#    u'has_humidifier': False,
#    u'has_x2_alt_heat': False,
#    u'has_x2_cool': False,
#    u'has_x2_heat': False,
#    u'has_x3_cool': False,
#    u'has_x3_heat': False,
#    u'heat_link_connection': 0,
#    u'heat_pump_aux_threshold': 10.0,
#    u'heat_pump_aux_threshold_enabled': True,
#    u'heat_pump_comp_threshold': -31.5,
#    u'heat_pump_comp_threshold_enabled': False,
#    u'heat_x2_delivery': u'forced-air',
#    u'heat_x2_source': u'gas',
#    u'heat_x3_delivery': u'forced-air',
#    u'heat_x3_source': u'gas',
#    u'heater_delivery': u'forced-air',
#    u'heater_source': u'gas',
#    u'heatpump_ready': False,
#    u'heatpump_savings': u'off',
#    u'heatpump_setback_active': False,
#    u'home_away_input': True,
#    u'hot_water_active': False,
#    u'hot_water_away_active': False,
#    u'hot_water_away_enabled': True,
#    u'hot_water_boiling_state': True,
#    u'humidifier_state': False,
#    u'humidifier_type': u'unknown',
#    u'humidity_control_lockout_enabled': False,
#    u'humidity_control_lockout_end_time': 0,
#    u'humidity_control_lockout_start_time': 0,
#    u'hvac_ac_state': False,
#    u'hvac_alt_heat_state': False,
#    u'hvac_alt_heat_x2_state': False,
#    u'hvac_aux_heater_state': False,
#    u'hvac_cool_x2_state': False,
#    u'hvac_cool_x3_state': False,
#    u'hvac_emer_heat_state': False,
#    u'hvac_fan_state': False,
#    u'hvac_heat_x2_state': False,
#    u'hvac_heat_x3_state': False,
#    u'hvac_heater_state': True,
#    u'hvac_pins': u'W1,Y1,Rh,G',
#    u'hvac_safety_shutoff_active': False,
#    u'hvac_smoke_safety_shutoff_active': False,
#    u'hvac_staging_ignore': False,
#    u'hvac_wires': u'Heat,Cool,Fan,Rh',
#    u'is_furnace_shutdown': False,
#    u'last_software_update_utc_secs': 1477962549,
#    u'leaf': False,
#    u'leaf_away_high': 28.87999,
#    u'leaf_away_low': 20.08333,
#    u'leaf_schedule_delta': 1.10999,
#    u'leaf_threshold_cool': 0.0,
#    u'leaf_threshold_heat': 22.23,
#    u'learning_days_completed_cool': 105,
#    u'learning_days_completed_heat': 122,
#    u'learning_days_completed_range': 72,
#    u'learning_mode': True,
#    u'learning_state': u'slow',
#    u'learning_time': 22,
#    u'local_ip': u'10.0.0.106',
#    u'logging_priority': u'informational',
#    u'lower_safety_temp': 7.22221,
#    u'lower_safety_temp_enabled': True,
#    u'mac_address': u'18b43071fa3a',
#    u'maint_band_lower': 0.39,
#    u'maint_band_upper': 0.39,
#    u'max_nighttime_preconditioning_seconds': 18000,
#    u'model_version': u'Display-3.4',
#    u'name': u'Oasis',
#    u'nlclient_state': u'',
#    u'note_codes': [],
#    u'ob_orientation': u'O',
#    u'ob_persistence': True,
#    u'oob_interview_completed': True,
#    u'oob_startup_completed': True,
#    u'oob_summary_completed': True,
#    u'oob_temp_completed': True,
#    u'oob_test_completed': True,
#    u'oob_where_completed': True,
#    u'oob_wifi_completed': True,
#    u'oob_wires_completed': True,
#    u'pin_c_description': u'none',
#    u'pin_g_description': u'fan',
#    u'pin_ob_description': u'none',
#    u'pin_rc_description': u'none',
#    u'pin_rh_description': u'power',
#    u'pin_star_description': u'none',
#    u'pin_w1_description': u'heat',
#    u'pin_w2aux_description': u'none',
#    u'pin_y1_description': u'cool',
#    u'pin_y2_description': u'none',
#    u'postal_code': u'43615',
#    u'preconditioning_active': False,
#    u'preconditioning_enabled': True,
#    u'preconditioning_ready': True,
#    u'pro_id': u'HP8A8A',
#    u'radiant_control_enabled': False,
#    u'range_enable': True,
#    u'rssi': 81.0,
#    u'safety_state': u'none',
#    u'safety_state_time': 1479600550,
#    u'safety_temp_activating_hvac': False,
#    u'schedule_learning_reset': False,
#    u'schedules': [],
#    u'serial_number': u'09AA01AC46150F2G',
#    u'should_wake_on_approach': True,
#    u'smoke_shutoff_supported': True,
#    u'star_type': u'unknown',
#    u'sunlight_correction_active': False,
#    u'sunlight_correction_enabled': False,
#    u'sunlight_correction_ready': False,
#    u'switch_system_off': False,
#    u'target_change_pending': False,
#    u'target_humidity': 35.0,
#    u'target_humidity_enabled': False,
#    u'target_temperature': 23.61053,
#    u'target_temperature_high': 24.0,
#    u'target_temperature_low': 20.0,
#    u'target_temperature_type': u'heat',
#    u'target_time_confidence': 0.0,
#    u'temperature_lock': False,
#    u'temperature_lock_high_temp': 22.222,
#    u'temperature_lock_low_temp': 20.0,
#    u'temperature_lock_pin_hash': u'',
#    u'temperature_scale': u'F',
#    u'time_to_target': 0,
#    u'time_to_target_training': u'ready',
#    u'tou_icon': False,
#    u'touched_by': {},
#    u'type': u'TBD',
#    u'upper_safety_temp': 35.062,
#    u'upper_safety_temp_enabled': True,
#    u'user_brightness': u'auto',
#    u'where_id': u'00000000-0000-0000-0000-00010000000c',
#    u'y2_type': u'unknown'}},
#  u'structure': {u'37051b70-b997-11e5-9399-22000b6d823e': {u'$timestamp': 1481233642475,
#    u'$version': 23485,
#    u'address_lines': [u'947 Linden Ln', u''],
#    u'away': False,
#    u'away_setter': 0,
#    u'away_timestamp': 1481233636,
#    u'city': u'Toledo',
#    u'clutches': [],
#    u'country_code': u'US',
#    u'creation_time': 1452649481898,
#    u'demand_charge_enabled': True,
#    u'demand_charge_speedbump_last_shown_epoch': 0,
#    u'devices': [u'device.09AA01AC46150F2G'],
#    u'diamond_changed_location': False,
#    u'dr_reminder_enabled': True,
#    u'eta_preconditioning_active': False,
#    u'fabric_ids': [],
#    u'geofence_enhanced_autoaway': {u'enabled': True, u'is_set': True},
#    u'goose_sensor_events_enabled': True,
#    u'house_type': u'condo',
#    u'hvac_safety_shutoff_enabled': True,
#    u'hvac_smoke_safety_shutoff_enabled': False,
#    u'latitude': 41.64928247854032,
#    u'location': u'Toledo, OH',
#    u'longitude': -83.65790577110907,
#    u'manual_away_timestamp': 1478392961,
#    u'measurement_scale': u'metric',
#    u'members': [{u'roles': [u'owner'], u'user': u'user.2925484'}],
#    u'name': u'Oasis',
#    u'num_thermostats': u'1',
#    u'postal_code': u'43615',
#    u'renovation_date': u'1990',
#    u'state': u'OH',
#    u'structure_area': 92.903,
#    u'swarm': [u'device.09AA01AC46150F2G'],
#    u'time_zone': u'America/New_York',
#    u'topaz_away': False,
#    u'topaz_enhanced_auto_away_enabled': False,
#    u'topaz_hush_key': u'riOcOwPbX6/glUeg6pY+Uw==',
#    u'tou_enabled': True,
#    u'tou_speedbump_count_remaining': 3,
#    u'tou_speedbump_last_shown_epoch': 0,
#    u'touched_by': {u'touched_by': 4,
#     u'touched_id': u'',
#     u'touched_user_id': u''},
#    u'user': u'user.2925484',
#    u'vacation_mode': False}},
#  u'structure_metadata': {u'37051b70-b997-11e5-9399-22000b6d823e': {u'$timestamp': 1452649481991,
#    u'$version': -20589}},
#  u'tou': {u'09AA01AC46150F2G': {u'$timestamp': 1, u'$version': -1}},
#  u'track': {u'09AA01AC46150F2G': {u'$timestamp': 1481603759742,
#    u'$version': 29991,
#    u'last_connection': 1481603759742,
#    u'last_ip': u'23.116.205.226',
#    u'online': True}},
#  u'trip': {u'37051b70-b997-11e5-9399-22000b6d823e': {u'$timestamp': 1452649481991,
#    u'$version': 9300,
#    u'trips': []}},
#  u'tuneups': {u'09AA01AC46150F2G': {u'$timestamp': 1480493859778,
#    u'$version': 29657}},
#  u'user': {u'2925484': {u'$timestamp': 1477019268282,
#    u'$version': -17447,
#    u'acknowledged_onboarding_screens': [u'eco'],
#    u'email': u'zorroxinxsindi@gmail.com',
#    u'name': u'zorroxinxsindi@gmail.com',
#    u'profile_image_url': u'https://home.nest.com/api/0.1/avatar/user/2925484/u=cb8b1c40-b997-11e5-b799-22000b680c71/v=562733476',
#    u'structure_memberships': [{u'roles': [u'owner'],
#      u'structure': u'structure.37051b70-b997-11e5-9399-22000b6d823e'}],
#    u'structures': [u'structure.37051b70-b997-11e5-9399-22000b6d823e']}},
#  u'user_alert_dialog': {u'2925484': {u'$timestamp': 1452649572044,
#    u'$version': 4635,
#    u'dialog_data': u'',
#    u'dialog_id': u'confirm-pairing'}},
#  u'user_settings': {u'2925484': {u'$timestamp': 1478393080849,
#    u'$version': 2767,
#    u'app_swu_minimum_version': {u'pairing': 2},
#    u'email_verified': True,
#    u'has_location_history': True,
#    u'lang': u'en_US',
#    u'location_primary_device': u'86089634-92B5-4EE8-AEE5-0D9891073970',
#    u'max_smoke_detectors': 36,
#    u'max_smoke_detectors_per_structure': 18,
#    u'max_structures': 2,
#    u'max_thermostats': 40,
#    u'max_thermostats_per_structure': 20,
#    u'max_wwn_devices': 20,
#    u'max_wwn_devices_per_structure': 10,
#    u'receive_marketing_emails': True,
#    u'receive_nest_emails': True,
#    u'receive_support_emails': True,
#    u'tos_accepted_version': 1434564000001,
#    u'tos_current_version': 1434564000001,
#    u'tos_minimum_version': 1434564000001}},
#  u'utility': {u'37051b70-b997-11e5-9399-22000b6d823e': {u'$timestamp': 1,
#    u'$version': -1}},
#  u'where': {u'37051b70-b997-11e5-9399-22000b6d823e': {u'$timestamp': 1452649481898,
#    u'$version': -25330,
#    u'wheres': [{u'name': u'Backyard',
#      u'where_id': u'00000000-0000-0000-0000-000100000011'},
#     {u'name': u'Basement',
#      u'where_id': u'00000000-0000-0000-0000-000100000001'},
#     {u'name': u'Bedroom',
#      u'where_id': u'00000000-0000-0000-0000-00010000000d'},
#     {u'name': u'Den', u'where_id': u'00000000-0000-0000-0000-000100000003'},
#     {u'name': u'Dining Room',
#      u'where_id': u'00000000-0000-0000-0000-000100000010'},
#     {u'name': u'Downstairs',
#      u'where_id': u'00000000-0000-0000-0000-000100000006'},
#     {u'name': u'Driveway',
#      u'where_id': u'00000000-0000-0000-0000-000100000012'},
#     {u'name': u'Entryway',
#      u'where_id': u'00000000-0000-0000-0000-000100000000'},
#     {u'name': u'Family Room',
#      u'where_id': u'00000000-0000-0000-0000-00010000000b'},
#     {u'name': u'Front Yard',
#      u'where_id': u'00000000-0000-0000-0000-000100000013'},
#     {u'name': u'Hallway',
#      u'where_id': u'00000000-0000-0000-0000-000100000002'},
#     {u'name': u'Kids Room',
#      u'where_id': u'00000000-0000-0000-0000-000100000008'},
#     {u'name': u'Kitchen',
#      u'where_id': u'00000000-0000-0000-0000-00010000000a'},
#     {u'name': u'Living Room',
#      u'where_id': u'00000000-0000-0000-0000-00010000000c'},
#     {u'name': u'Master Bedroom',
#      u'where_id': u'00000000-0000-0000-0000-000100000005'},
#     {u'name': u'Office', u'where_id': u'00000000-0000-0000-0000-00010000000e'},
#     {u'name': u'Outside',
#      u'where_id': u'00000000-0000-0000-0000-000100000014'},
#     {u'name': u'Upstairs',
#      u'where_id': u'00000000-0000-0000-0000-00010000000f'}]}}}

# %%
with open('data.json', 'w') as outfile:
    json.dump(n.status["device"]['09AA01AC46150F2G'], outfile)

# %%
print len(n.status)
dir(n.status)
# Out:
# 25
# ['__class__',
#  '__cmp__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'has_key',
#  'items',
#  'iteritems',
#  'iterkeys',
#  'itervalues',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values',
#  'viewitems',
#  'viewkeys',
#  'viewvalues']

# %%
for item in n.status:
    print item, n.status[str(item)],'\n'
# Out:
# user_alert_dialog {u'2925484': {u'$version': 4635, u'dialog_id': u'confirm-pairing', u'dialog_data': u'', u'$timestamp': 1452649572044}}
#
# demand_response {u'09AA01AC46150F2G': {u'$version': -1, u'$timestamp': 1}}
#
# message_center {u'2925484': {u'$version': 1537, u'messages': [{u'parameters': [u'zorroxinxsindi@gmail.com'], u'read': True, u'timestamp': 1481546163, u'dismissed': True, u'priority': 2, u'thread_id': 0, u'key': u'mobile_device_health_check_fail', u'id': u'6d9fd500-c065-11e6-8826-22000acb84ae'}], u'$timestamp': 1481564517253}}
#
# message {u'09AA01AC46150F2G': {u'$version': 26113, u'$timestamp': 1477199673237}}
#
# trip {u'37051b70-b997-11e5-9399-22000b6d823e': {u'$version': 9300, u'trips': [], u'$timestamp': 1452649481991}}
#
# utility {u'37051b70-b997-11e5-9399-22000b6d823e': {u'$version': -1, u'$timestamp': 1}}
#
# user_settings {u'2925484': {u'lang': u'en_US', u'tos_current_version': 1434564000001, u'tos_accepted_version': 1434564000001, u'max_wwn_devices_per_structure': 10, u'tos_minimum_version': 1434564000001, u'receive_marketing_emails': True, u'receive_nest_emails': True, u'app_swu_minimum_version': {u'pairing': 2}, u'email_verified': True, u'max_thermostats': 40, u'max_smoke_detectors': 36, u'max_thermostats_per_structure': 20, u'has_location_history': True, u'max_structures': 2, u'max_smoke_detectors_per_structure': 18, u'$version': 2767, u'max_wwn_devices': 20, u'location_primary_device': u'86089634-92B5-4EE8-AEE5-0D9891073970', u'$timestamp': 1478393080849, u'receive_support_emails': True}}
#
# tou {u'09AA01AC46150F2G': {u'$version': -1, u'$timestamp': 1}}
#
# safety {u'37051b70-b997-11e5-9399-22000b6d823e': {u'$version': -7879, u'$timestamp': 1452649481991, u'audio_self_test_participants': []}}
#
# shared {u'09AA01AC46150F2G': {u'compressor_lockout_timeout': 0, u'tou_icon': False, u'max_nighttime_preconditioning_seconds': 18000, u'country_code': u'US', u'fan_timer_duration': 1800, u'hvac_wires': u'Heat,Cool,Fan,Rh', u'humidifier_type': u'unknown', u'sunlight_correction_active': False, u'target_temperature_low': 20.0, u'temperature_lock': False, u'has_x3_heat': False, u'alt_heat_x2_delivery': u'forced-air', u'oob_startup_completed': True, u'should_wake_on_approach': True, u'has_fan': True, u'pin_rh_description': u'power', u'has_x2_alt_heat': False, u'heat_x2_source': u'gas', u'filter_changed_date': 1479168000, u'equipment_type': u'electric', u'forced_air': True, u'can_cool': True, u'aux_lockout_leaf': 10.0, u'humidifier_state': False, u'error_code': u'', u'learning_mode': True, u'eco_onboarding_needed': True, u'creation_time': 1452649087971, u'heat_pump_comp_threshold_enabled': False, u'pin_star_description': u'none', u'learning_days_completed_cool': 105, u'away_temperature_low_enabled': True, u'home_away_input': True, u'y2_type': u'unknown', u'auto_dehum_enabled': True, u'hvac_aux_heater_state': False, u'gear_threshold_high': 0.0, u'target_temperature_high': 24.0, u'logging_priority': u'informational', u'dehumidifier_orientation_selected': u'unknown', u'oob_wifi_completed': True, u'target_temperature_type': u'heat', u'ob_persistence': True, u'hvac_safety_shutoff_active': False, u'schedule_learning_reset': False, u'pin_y2_description': u'none', u'filter_reminder_enabled': True, u'rssi': 81.0, u'away_temperature_high': 30.278, u'fan_duty_start_time': 0, u'target_humidity_enabled': False, u'sunlight_correction_ready': False, u'safety_temp_activating_hvac': False, u'model_version': u'Display-3.4', u'oob_test_completed': True, u'safety_state': u'none', u'can_heat': True, u'alt_heat_delivery': u'forced-air', u'target_humidity': 35.0, u'preconditioning_ready': True, u'backplate_mono_version': u'1.2.9', u'cooling_source': u'electric', u'hvac_staging_ignore': False, u'type': u'TBD', u'lower_safety_temp': 7.22221, u'hvac_heater_state': True, u'fan_current_speed': u'off', u'fan_cooling_enabled': True, u'learning_days_completed_heat': 122, u'radiant_control_enabled': False, u'where_id': u'00000000-0000-0000-0000-00010000000c', u'auto_away_reset': False, u'humidity_control_lockout_enabled': False, u'heatpump_ready': False, u'oob_summary_completed': True, u'has_air_filter': True, u'cooling_x2_source': u'electric', u'temperature_lock_high_temp': 22.222, u'learning_days_completed_range': 72, u'fan_schedule_speed': u'stage1', u'fan_timer_timeout': 0, u'has_alt_heat': False, u'backplate_bsl_version': u'3.1', u'user_brightness': u'auto', u'upper_safety_temp': 35.062, u'pin_rc_description': u'none', u'pro_id': u'HP8A8A', u'has_dehumidifier': False, u'hvac_cool_x3_state': False, u'capability_level': 5.6, u'available_locales': u'en_US,fr_CA,es_US,en_GB,fr_FR,nl_NL', u'dehumidifier_state': False, u'is_furnace_shutdown': False, u'demand_charge_icon': False, u'leaf_threshold_cool': 0.0, u'upper_safety_temp_enabled': True, u'learning_state': u'slow', u'time_to_target_training': u'ready', u'fan_cooling_state': False, u'fan_duty_end_time': 25200, u'pin_y1_description': u'cool', u'$timestamp': 1481600788882, u'heat_link_connection': 0, u'temperature_lock_pin_hash': u'', u'cooling_delivery': u'unknown', u'heat_pump_aux_threshold_enabled': True, u'leaf_away_low': 20.08333, u'touched_by': {}, u'emer_heat_enable': False, u'pin_g_description': u'fan', u'local_ip': u'10.0.0.106', u'hvac_alt_heat_x2_state': False, u'has_x2_heat': False, u'oob_where_completed': True, u'away_temperature_high_adjusted': 30.278, u'heater_source': u'gas', u'last_software_update_utc_secs': 1477962549, u'hvac_ac_state': False, u'heat_pump_comp_threshold': -31.5, u'leaf_away_high': 28.87999, u'gear_threshold_low': 0.0, u'star_type': u'unknown', u'oob_temp_completed': True, u'postal_code': u'43615', u'heater_delivery': u'forced-air', u'heat_x3_source': u'gas', u'backplate_serial_nu ...
#
# structure_metadata {u'37051b70-b997-11e5-9399-22000b6d823e': {u'$version': -20589, u'$timestamp': 1452649481991}}
#
# metadata {u'09AA01AC46150F2G': {u'$version': -1, u'last_ip': u'127.0.0.1', u'last_connection': 1356998400000, u'$timestamp': 1356998400000}}
#
# schedule {u'09AA01AC46150F2G': {u'ver': 2, u'name': u'Current Schedule', u'days': {u'1': {u'1': {u'touched_tzo': -18000, u'temp': 20.08333, u'entry_type': u'setpoint', u'touched_user_id': u'user.2925484', u'touched_at': 1481474472, u'time': 3600, u'touched_by': 6, u'type': u'HEAT'}, u'0': {u'touched_tzo': -18000, u'temp': 23.5, u'entry_type': u'continuation', u'touched_at': 1481474493, u'time': 0, u'touched_by': 1, u'type': u'HEAT'}, u'3': {u'touched_tzo': -18000, u'temp': 23.5, u'entry_type': u'setpoint', u'touched_user_id': u'user.2925484', u'touched_at': 1481474472, u'time': 44100, u'touched_by': 6, u'type': u'HEAT'}, u'2': {u'touched_tzo': -18000, u'temp': 24.23984, u'entry_type': u'setpoint', u'touched_user_id': u'user.2925484', u'touched_at': 1481474472, u'time': 25200, u'touched_by': 6, u'type': u'HEAT'}}, u'0': {u'1': {u'touched_tzo': -18000, u'temp': 20.08333, u'entry_type': u'setpoint', u'touched_user_id': u'user.2925484', u'touched_at': 1481474474, u'time': 3600, u'touched_by': 6, u'type': u'HEAT'}, u'0': {u'touched_tzo': -18000, u'temp': 23.5, u'entry_type': u'continuation', u'touched_at': 1481474493, u'time': 0, u'touched_by': 1, u'type': u'HEAT'}, u'3': {u'touched_tzo': -18000, u'temp': 23.5, u'entry_type': u'setpoint', u'touched_user_id': u'user.2925484', u'touched_at': 1481474474, u'time': 44100, u'touched_by': 6, u'type': u'HEAT'}, u'2': {u'touched_tzo': -18000, u'temp': 24.23984, u'entry_type': u'setpoint', u'touched_user_id': u'user.2925484', u'touched_at': 1481474474, u'time': 25200, u'touched_by': 6, u'type': u'HEAT'}}, u'3': {u'1': {u'touched_tzo': -18000, u'temp': 20.08333, u'entry_type': u'setpoint', u'touched_user_id': u'user.2925484', u'touched_at': 1481430340, u'time': 3600, u'touched_by': 6, u'type': u'HEAT'}, u'0': {u'touched_tzo': -18000, u'temp': 23.5, u'entry_type': u'continuation', u'touched_at': 1481474493, u'time': 0, u'touched_by': 1, u'type': u'HEAT'}, u'3': {u'touched_tzo': -18000, u'temp': 23.5, u'entry_type': u'setpoint', u'touched_user_id': u'user.2925484', u'touched_at': 1481430340, u'time': 44100, u'touched_by': 6, u'type': u'HEAT'}, u'2': {u'touched_tzo': -18000, u'temp': 24.23984, u'entry_type': u'setpoint', u'touched_user_id': u'user.2925484', u'touched_at': 1481474466, u'time': 25200, u'touched_by': 6, u'type': u'HEAT'}}, u'2': {u'1': {u'touched_tzo': -18000, u'temp': 20.08333, u'entry_type': u'setpoint', u'touched_user_id': u'user.2925484', u'touched_at': 1481474471, u'time': 3600, u'touched_by': 6, u'type': u'HEAT'}, u'0': {u'touched_tzo': -18000, u'temp': 23.5, u'entry_type': u'continuation', u'touched_at': 1481474493, u'time': 0, u'touched_by': 1, u'type': u'HEAT'}, u'3': {u'touched_tzo': -18000, u'temp': 23.5, u'entry_type': u'setpoint', u'touched_user_id': u'user.2925484', u'touched_at': 1481474471, u'time': 44100, u'touched_by': 6, u'type': u'HEAT'}, u'2': {u'touched_tzo': -18000, u'temp': 24.23984, u'entry_type': u'setpoint', u'touched_user_id': u'user.2925484', u'touched_at': 1481474471, u'time': 25200, u'touched_by': 6, u'type': u'HEAT'}}, u'5': {u'1': {u'touched_tzo': -18000, u'temp': 20.08333, u'entry_type': u'setpoint', u'touched_user_id': u'user.2925484', u'touched_at': 1481430336, u'time': 3600, u'touched_by': 6, u'type': u'HEAT'}, u'0': {u'touched_tzo': -18000, u'temp': 23.5, u'entry_type': u'continuation', u'touched_at': 1481474493, u'time': 0, u'touched_by': 1, u'type': u'HEAT'}, u'3': {u'touched_tzo': -18000, u'temp': 23.5, u'entry_type': u'setpoint', u'touched_user_id': u'user.2925484', u'touched_at': 1481430336, u'time': 44100, u'touched_by': 6, u'type': u'HEAT'}, u'2': {u'touched_tzo': -18000, u'temp': 24.23984, u'entry_type': u'setpoint', u'touched_user_id': u'user.2925484', u'touched_at': 1481430336, u'time': 32400, u'touched_by': 6, u'type': u'HEAT'}}, u'4': {u'1': {u'touched_tzo': -18000, u'temp': 20.08333, u'entry_type': u'setpoint', u'touched_user_id': u'user.2925484', u'touched_at': 1481474437, u'time': 3600, u'touched_by': 6, u'type': u'HEAT'}, u'0':  ...
#
# track {u'09AA01AC46150F2G': {u'$version': 29991, u'last_ip': u'23.116.205.226', u'last_connection': 1481603759742, u'$timestamp': 1481603759742, u'online': True}}
#
# buckets {u'2925484': {u'$version': -22704, u'buckets': [u'user.2925484', u'user_alert_dialog.2925484', u'message_center.2925484', u'user_settings.2925484', u'buckets.2925484', u'device.09AA01AC46150F2G', u'demand_response.09AA01AC46150F2G', u'device_alert_dialog.09AA01AC46150F2G', u'link.09AA01AC46150F2G', u'message.09AA01AC46150F2G', u'metadata.09AA01AC46150F2G', u'schedule.09AA01AC46150F2G', u'shared.09AA01AC46150F2G', u'track.09AA01AC46150F2G', u'tuneups.09AA01AC46150F2G', u'energy_latest.09AA01AC46150F2G', u'energy_weekly.09AA01AC46150F2G', u'tou.09AA01AC46150F2G', u'demand_charge.09AA01AC46150F2G', u'structure.37051b70-b997-11e5-9399-22000b6d823e', u'where.37051b70-b997-11e5-9399-22000b6d823e', u'utility.37051b70-b997-11e5-9399-22000b6d823e', u'structure_history.37051b70-b997-11e5-9399-22000b6d823e', u'trip.37051b70-b997-11e5-9399-22000b6d823e', u'structure_metadata.37051b70-b997-11e5-9399-22000b6d823e', u'safety.37051b70-b997-11e5-9399-22000b6d823e', u'safety_summary.37051b70-b997-11e5-9399-22000b6d823e', u'geofence_info.37051b70-b997-11e5-9399-22000b6d823e'], u'$timestamp': 1480498030799}}
#
# device_alert_dialog {u'09AA01AC46150F2G': {u'$version': -26252, u'dialog_id': u'confirm-pairing', u'dialog_data': u'', u'$timestamp': 1452649572044}}
#
# link {u'09AA01AC46150F2G': {u'$version': -2397, u'structure': u'structure.37051b70-b997-11e5-9399-22000b6d823e', u'$timestamp': 1452649572044}}
#
# user {u'2925484': {u'structure_memberships': [{u'roles': [u'owner'], u'structure': u'structure.37051b70-b997-11e5-9399-22000b6d823e'}], u'name': u'zorroxinxsindi@gmail.com', u'profile_image_url': u'https://home.nest.com/api/0.1/avatar/user/2925484/u=cb8b1c40-b997-11e5-b799-22000b680c71/v=562733476', u'$version': -17447, u'structures': [u'structure.37051b70-b997-11e5-9399-22000b6d823e'], u'email': u'zorroxinxsindi@gmail.com', u'$timestamp': 1477019268282, u'acknowledged_onboarding_screens': [u'eco']}}
#
# device {u'09AA01AC46150F2G': {u'heat_pump_comp_threshold': -31.5, u'leaf_away_high': 28.87999, u'schedules': [], u'tou_icon': False, u'max_nighttime_preconditioning_seconds': 18000, u'oob_temp_completed': True, u'postal_code': u'43615', u'heater_delivery': u'forced-air', u'country_code': u'US', u'star_type': u'unknown', u'heat_x3_source': u'gas', u'fan_timer_duration': 1800, u'backplate_serial_number': u'09DA01AC44150M4L', u'hvac_wires': u'Heat,Cool,Fan,Rh', u'humidifier_type': u'unknown', u'sunlight_correction_active': False, u'backplate_bsl_info': u'BSL', u'temperature_lock': False, u'auto_away_reset': False, u'dual_fuel_breakpoint_override': u'none', u'has_x3_heat': False, u'oob_wifi_completed': True, u'alt_heat_x2_delivery': u'forced-air', u'oob_startup_completed': True, u'maint_band_lower': 0.39, u'device_locale': u'en_US', u'learning_time': 22, u'should_wake_on_approach': True, u'gear_threshold_low': 0.0, u'has_fan': True, u'auto_dehum_state': False, u'lower_safety_temp_enabled': True, u'backplate_model': u'Backplate-5.3', u'heat_x2_source': u'gas', u'aux_heat_source': u'electric', u'filter_changed_date': 1479168000, u'last_software_update_utc_secs': 1477962549, u'equipment_type': u'electric', u'heat_pump_comp_threshold_enabled': False, u'dehumidifier_orientation_selected': u'unknown', u'forced_air': True, u'cooling_x3_delivery': u'unknown', u'aux_lockout_leaf': 10.0, u'away_temperature_high_adjusted': 30.278, u'filter_reminder_level': 0, u'humidifier_state': False, u'error_code': u'', u'learning_mode': True, u'has_x2_cool': False, u'hot_water_away_enabled': True, u'hvac_pins': u'W1,Y1,Rh,G', u'preconditioning_ready': True, u'eco_onboarding_needed': True, u'switch_system_off': False, u'creation_time': 1452649087971, u'serial_number': u'09AA01AC46150F2G', u'pin_star_description': u'none', u'has_aux_heat': False, u'learning_days_completed_cool': 105, u'away_temperature_low_enabled': True, u'home_away_input': True, u'note_codes': [], u'leaf_threshold_heat': 22.23, u'y2_type': u'unknown', u'auto_dehum_enabled': True, u'temperature_scale': u'F', u'time_to_target': 0, u'alt_heat_x2_source': u'gas', u'has_humidifier': False, u'gear_threshold_high': 0.0, u'current_schedule_mode': u'HEAT', u'logging_priority': u'informational', u'fan_timer_speed': u'stage1', u'fan_cooling_readiness': u'ready', u'safety_state': u'none', u'battery_level': 3.871, u'humidity_control_lockout_end_time': 0, u'eco': {u'touched_by': 6, u'mode': u'schedule', u'mode_update_timestamp': 1481409207}, u'ob_persistence': True, u'hvac_safety_shutoff_active': False, u'schedule_learning_reset': False, u'pin_y2_description': u'none', u'emer_heat_source': u'electric', u'filter_reminder_enabled': True, u'rssi': 81.0, u'$version': 3965, u'leaf_away_low': 20.08333, u'filter_changed_set_date': 1478853676, u'aux_heat_delivery': u'forced-air', u'smoke_shutoff_supported': True, u'away_temperature_high': 30.278, u'fan_duty_start_time': 0, u'target_humidity_enabled': False, u'pin_rh_description': u'power', u'leaf_threshold_cool': 0.0, u'sunlight_correction_ready': False, u'fan_timer_timeout': 0, u'has_hot_water_control': False, u'farsight_screen': u'target_temp', u'safety_temp_activating_hvac': False, u'has_dual_fuel': False, u'cooling_x3_source': u'electric', u'heatpump_setback_active': False, u'compressor_lockout_leaf': -17.79999, u'has_heat_pump': False, u'fan_control_state': False, u'model_version': u'Display-3.4', u'oob_test_completed': True, u'sunlight_correction_enabled': False, u'current_version': u'5.6-7', u'away_temperature_high_enabled': True, u'alt_heat_delivery': u'forced-air', u'current_humidity': 42, u'target_humidity': 35.0, u'where_id': u'00000000-0000-0000-0000-00010000000c', u'backplate_mono_version': u'1.2.9', u'has_fossil_fuel': True, u'mac_address': u'18b43071fa3a', u'temperature_lock_low_temp': 20.0, u'has_hot_water_temperature': False, u'type': u'TBD', u'lower_safety_temp': 7.22221, u'preconditioning_active': False, u'hvac_smoke_safety_shutoff_active': ...
#
# structure {u'37051b70-b997-11e5-9399-22000b6d823e': {u'geofence_enhanced_autoaway': {u'enabled': True, u'is_set': True}, u'country_code': u'US', u'hvac_safety_shutoff_enabled': True, u'eta_preconditioning_active': False, u'creation_time': 1452649481898, u'away_timestamp': 1481233636, u'manual_away_timestamp': 1478392961, u'$version': 23485, u'postal_code': u'43615', u'devices': [u'device.09AA01AC46150F2G'], u'measurement_scale': u'metric', u'dr_reminder_enabled': True, u'tou_speedbump_count_remaining': 3, u'city': u'Toledo', u'goose_sensor_events_enabled': True, u'topaz_hush_key': u'riOcOwPbX6/glUeg6pY+Uw==', u'hvac_smoke_safety_shutoff_enabled': False, u'structure_area': 92.903, u'away': False, u'swarm': [u'device.09AA01AC46150F2G'], u'state': u'OH', u'location': u'Toledo, OH', u'fabric_ids': [], u'latitude': 41.64928247854032, u'away_setter': 0, u'$timestamp': 1481233642475, u'num_thermostats': u'1', u'clutches': [], u'tou_enabled': True, u'demand_charge_enabled': True, u'topaz_enhanced_auto_away_enabled': False, u'user': u'user.2925484', u'members': [{u'user': u'user.2925484', u'roles': [u'owner']}], u'topaz_away': False, u'touched_by': {u'touched_by': 4, u'touched_id': u'', u'touched_user_id': u''}, u'house_type': u'condo', u'demand_charge_speedbump_last_shown_epoch': 0, u'address_lines': [u'947 Linden Ln', u''], u'name': u'Oasis', u'renovation_date': u'1990', u'vacation_mode': False, u'time_zone': u'America/New_York', u'longitude': -83.65790577110907, u'tou_speedbump_last_shown_epoch': 0, u'diamond_changed_location': False}}
#
# demand_charge {u'09AA01AC46150F2G': {u'$version': -1, u'$timestamp': 1}}
#
# geofence_info {u'37051b70-b997-11e5-9399-22000b6d823e': {u'$version': -27010, u'device_events': [{u'events': [{u'time_state_reported': 1481328968000, u'time_of_state_transition': 1481328968000, u'user_id': u'2925484', u'state': 0, u'fence_id': u'37051b70-b997-11e5-9399-22000b6d823e:rzCzX1Zc'}], u'is_attached_to_occupancy': True, u'is_primary_device': True, u'device_id': u'86089634-92B5-4EE8-AEE5-0D9891073970'}], u'fences': [{u'latitude': 41.64928247854032, u'direction': [0, 1], u'radius': 200, u'fence_id': u'37051b70-b997-11e5-9399-22000b6d823e:rzCzX1Zc', u'longitude': -83.65790577110907}], u'combined_presence': {u'presence_evaluation_timestamp': 1481328968000, u'presence': 0}, u'$timestamp': 1481587521391}}
#
# tuneups {u'09AA01AC46150F2G': {u'$version': 29657, u'$timestamp': 1480493859778}}
#
# safety_summary {u'37051b70-b997-11e5-9399-22000b6d823e': {u'$version': -25109, u'$timestamp': 1452649481991}}
#
# where {u'37051b70-b997-11e5-9399-22000b6d823e': {u'$version': -25330, u'wheres': [{u'where_id': u'00000000-0000-0000-0000-000100000011', u'name': u'Backyard'}, {u'where_id': u'00000000-0000-0000-0000-000100000001', u'name': u'Basement'}, {u'where_id': u'00000000-0000-0000-0000-00010000000d', u'name': u'Bedroom'}, {u'where_id': u'00000000-0000-0000-0000-000100000003', u'name': u'Den'}, {u'where_id': u'00000000-0000-0000-0000-000100000010', u'name': u'Dining Room'}, {u'where_id': u'00000000-0000-0000-0000-000100000006', u'name': u'Downstairs'}, {u'where_id': u'00000000-0000-0000-0000-000100000012', u'name': u'Driveway'}, {u'where_id': u'00000000-0000-0000-0000-000100000000', u'name': u'Entryway'}, {u'where_id': u'00000000-0000-0000-0000-00010000000b', u'name': u'Family Room'}, {u'where_id': u'00000000-0000-0000-0000-000100000013', u'name': u'Front Yard'}, {u'where_id': u'00000000-0000-0000-0000-000100000002', u'name': u'Hallway'}, {u'where_id': u'00000000-0000-0000-0000-000100000008', u'name': u'Kids Room'}, {u'where_id': u'00000000-0000-0000-0000-00010000000a', u'name': u'Kitchen'}, {u'where_id': u'00000000-0000-0000-0000-00010000000c', u'name': u'Living Room'}, {u'where_id': u'00000000-0000-0000-0000-000100000005', u'name': u'Master Bedroom'}, {u'where_id': u'00000000-0000-0000-0000-00010000000e', u'name': u'Office'}, {u'where_id': u'00000000-0000-0000-0000-000100000014', u'name': u'Outside'}, {u'where_id': u'00000000-0000-0000-0000-00010000000f', u'name': u'Upstairs'}], u'$timestamp': 1452649481898}}

# %%
x = n.status["device"]['09AA01AC46150F2G']
#x = sorted(x)
#type(x)
# type(x.keys()[1])
#print x.keys(), ':',x.values(),'\n'

#@print x.keys()[10], ' ', type(x.keys()[10])

type(x['$timestamp'])
# Out:
# int

# %%
x = sorted(x)
type(x)
# Out:
# list

# %%
x = n.status["device"]['09AA01AC46150F2G']

for item in sorted(x):
    print item,':', x[str(item)]
# Out:
# $timestamp : 1481600788882
# $version : 3965
# alt_heat_delivery : forced-air
# alt_heat_source : gas
# alt_heat_x2_delivery : forced-air
# alt_heat_x2_source : gas
# auto_away_enable : True
# auto_away_reset : False
# auto_dehum_enabled : True
# auto_dehum_state : False
# aux_heat_delivery : forced-air
# aux_heat_source : electric
# aux_lockout_leaf : 10.0
# available_locales : en_US,fr_CA,es_US,en_GB,fr_FR,nl_NL
# away_temperature_high : 30.278
# away_temperature_high_adjusted : 30.278
# away_temperature_high_enabled : True
# away_temperature_low : 10.39597
# away_temperature_low_adjusted : 10.39597
# away_temperature_low_enabled : True
# backplate_bsl_info : BSL
# backplate_bsl_version : 3.1
# backplate_model : Backplate-5.3
# backplate_mono_info : TFE (BP_D3) 1.2.9 (root@sticks.pao.corp.google.com) 2016-08-17 12:36:42
# backplate_mono_version : 1.2.9
# backplate_serial_number : 09DA01AC44150M4L
# battery_level : 3.871
# capability_level : 5.6
# click_sound : on
# compressor_lockout_leaf : -17.79999
# cooling_delivery : unknown
# cooling_source : electric
# cooling_x2_delivery : unknown
# cooling_x2_source : electric
# cooling_x3_delivery : unknown
# cooling_x3_source : electric
# country_code : US
# creation_time : 1452649087971
# current_humidity : 42
# current_schedule_mode : HEAT
# current_version : 5.6-7
# dehumidifier_orientation_selected : unknown
# dehumidifier_state : False
# dehumidifier_type : unknown
# demand_charge_icon : False
# device_locale : en_US
# dual_fuel_breakpoint : -1.0
# dual_fuel_breakpoint_override : none
# eco : {u'touched_by': 6, u'mode': u'schedule', u'mode_update_timestamp': 1481409207}
# eco_onboarding_needed : True
# emer_heat_delivery : forced-air
# emer_heat_enable : False
# emer_heat_source : electric
# equipment_type : electric
# error_code :
# fan_capabilities : stage1
# fan_control_state : False
# fan_cooling_enabled : True
# fan_cooling_readiness : ready
# fan_cooling_state : False
# fan_current_speed : off
# fan_duty_cycle : 900
# fan_duty_end_time : 25200
# fan_duty_start_time : 0
# fan_heat_cool_speed : auto
# fan_mode : auto
# fan_schedule_speed : stage1
# fan_timer_duration : 1800
# fan_timer_speed : stage1
# fan_timer_timeout : 0
# farsight_screen : target_temp
# filter_changed_date : 1479168000
# filter_changed_set_date : 1478853676
# filter_reminder_enabled : True
# filter_reminder_level : 0
# forced_air : True
# gear_threshold_high : 0.0
# gear_threshold_low : 0.0
# has_air_filter : True
# has_alt_heat : False
# has_aux_heat : False
# has_dehumidifier : False
# has_dual_fuel : False
# has_emer_heat : False
# has_fan : True
# has_fossil_fuel : True
# has_heat_pump : False
# has_hot_water_control : False
# has_hot_water_temperature : False
# has_humidifier : False
# has_x2_alt_heat : False
# has_x2_cool : False
# has_x2_heat : False
# has_x3_cool : False
# has_x3_heat : False
# heat_link_connection : 0
# heat_pump_aux_threshold : 10.0
# heat_pump_aux_threshold_enabled : True
# heat_pump_comp_threshold : -31.5
# heat_pump_comp_threshold_enabled : False
# heat_x2_delivery : forced-air
# heat_x2_source : gas
# heat_x3_delivery : forced-air
# heat_x3_source : gas
# heater_delivery : forced-air
# heater_source : gas
# heatpump_ready : False
# heatpump_savings : off
# heatpump_setback_active : False
# home_away_input : True
# hot_water_active : False
# hot_water_away_active : False
# hot_water_away_enabled : True
# hot_water_boiling_state : True
# humidifier_state : False
# humidifier_type : unknown
# humidity_control_lockout_enabled : False
# humidity_control_lockout_end_time : 0
# humidity_control_lockout_start_time : 0
# hvac_pins : W1,Y1,Rh,G
# hvac_safety_shutoff_active : False
# hvac_smoke_safety_shutoff_active : False
# hvac_staging_ignore : False
# hvac_wires : Heat,Cool,Fan,Rh
# is_furnace_shutdown : False
# last_software_update_utc_secs : 1477962549
# leaf : False
# leaf_away_high : 28.87999
# leaf_away_low : 20.08333
# leaf_schedule_delta : 1.10999
# leaf_threshold_cool : 0.0
# leaf_threshold_heat : 22.23
# learning_days_completed_cool : 105
# learning_days_completed_heat : 122
# learning_days_completed_range : 72
# learning_mode : True
# learning_state : slow
# learning_time : 22
# local_ip : 10.0.0.106
# logging_priority : informational
# lower_safety_temp : 7.22221
# lower_safety_temp_enabled : True
# mac_address : 18b43071fa3a
# maint_band_lower : 0.39
# maint_band_upper : 0.39
# max_nighttime_preconditioning_seconds : 18000
# model_version : Display-3.4
# nlclient_state :
# note_codes : []
# ob_orientation : O
# ob_persistence : True
# oob_interview_completed : True
# oob_startup_completed : True
# oob_summary_completed : True
# oob_temp_completed : True
# oob_test_completed : True
# oob_where_completed : True
# oob_wifi_completed : True
# oob_wires_completed : True
# pin_c_description : none
# pin_g_description : fan
# pin_ob_description : none
# pin_rc_description : none
# pin_rh_description : power
# pin_star_description : none
# pin_w1_description : heat
# pin_w2aux_description : none
# pin_y1_description : cool
# pin_y2_description : none
# postal_code : 43615
# preconditioning_active : False
# preconditioning_enabled : True
# preconditioning_ready : True
# pro_id : HP8A8A
# radiant_control_enabled : False
# range_enable : True
# rssi : 81.0
# safety_state : none
# safety_state_time : 1479600550
# safety_temp_activating_hvac : False
# schedule_learning_reset : False
# schedules : []
# serial_number : 09AA01AC46150F2G
# should_wake_on_approach : True
# smoke_shutoff_supported : True
# star_type : unknown
# sunlight_correction_active : False
# sunlight_correction_enabled : False
# sunlight_correction_ready : False
# switch_system_off : False
# target_humidity : 35.0
# target_humidity_enabled : False
# target_time_confidence : 0.0
# temperature_lock : False
# temperature_lock_high_temp : 22.222
# temperature_lock_low_temp : 20.0
# temperature_lock_pin_hash :
# temperature_scale : F
# time_to_target : 0
# time_to_target_training : ready
# tou_icon : False
# touched_by : {}
# type : TBD
# upper_safety_temp : 35.062
# upper_safety_temp_enabled : True
# user_brightness : auto
# where_id : 00000000-0000-0000-0000-00010000000c
# y2_type : unknown

# %%
y = x.keys()
type(y)
# Out:
# list

# %%
type(x)
# Out:
# dict

# %%
qmarks = ', '.join('?' * len(x))
print qmarks
# Out:
# ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?

# %%
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-87-2b100770cf46> in <module>()
# ----> 1 info = json.loads(n.status)
#
# /usr/lib/python2.7/json/__init__.pyc in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337             parse_int is None and parse_float is None and
#     338             parse_constant is None and object_pairs_hook is None and not kw):
# --> 339         return _default_decoder.decode(s)
#     340     if cls is None:
#     341         cls = JSONDecoder
#
# /usr/lib/python2.7/json/decoder.pyc in decode(self, s, _w)
#     362
#     363         """
# --> 364         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     365         end = _w(s, end).end()
#     366         if end != len(s):
#
# TypeError: expected string or buffer

# %%
n.status["device"]['09AA01AC46150F2G']
# Out:
# {u'$timestamp': 1481648378169,
#  u'$version': -7418,
#  u'alt_heat_delivery': u'forced-air',
#  u'alt_heat_source': u'gas',
#  u'alt_heat_x2_delivery': u'forced-air',
#  u'alt_heat_x2_source': u'gas',
#  u'auto_away_enable': True,
#  u'auto_away_reset': False,
#  u'auto_dehum_enabled': True,
#  u'auto_dehum_state': False,
#  u'aux_heat_delivery': u'forced-air',
#  u'aux_heat_source': u'electric',
#  u'aux_lockout_leaf': 10.0,
#  u'available_locales': u'en_US,fr_CA,es_US,en_GB,fr_FR,nl_NL',
#  u'away_temperature_high': 30.278,
#  u'away_temperature_high_adjusted': 30.278,
#  u'away_temperature_high_enabled': True,
#  u'away_temperature_low': 10.39597,
#  u'away_temperature_low_adjusted': 10.39597,
#  u'away_temperature_low_enabled': True,
#  u'backplate_bsl_info': u'BSL',
#  u'backplate_bsl_version': u'3.1',
#  u'backplate_model': u'Backplate-5.3',
#  u'backplate_mono_info': u'TFE (BP_D3) 1.2.9 (root@sticks.pao.corp.google.com) 2016-08-17 12:36:42',
#  u'backplate_mono_version': u'1.2.9',
#  u'backplate_serial_number': u'09DA01AC44150M4L',
#  u'battery_level': 3.904,
#  u'capability_level': 5.6,
#  u'click_sound': u'on',
#  u'compressor_lockout_leaf': -17.79999,
#  u'cooling_delivery': u'unknown',
#  u'cooling_source': u'electric',
#  u'cooling_x2_delivery': u'unknown',
#  u'cooling_x2_source': u'electric',
#  u'cooling_x3_delivery': u'unknown',
#  u'cooling_x3_source': u'electric',
#  u'country_code': u'US',
#  u'creation_time': 1452649087971,
#  u'current_humidity': 34,
#  u'current_schedule_mode': u'HEAT',
#  u'current_version': u'5.6-7',
#  u'dehumidifier_orientation_selected': u'unknown',
#  u'dehumidifier_state': False,
#  u'dehumidifier_type': u'unknown',
#  u'demand_charge_icon': False,
#  u'device_locale': u'en_US',
#  u'dual_fuel_breakpoint': -1.0,
#  u'dual_fuel_breakpoint_override': u'none',
#  u'eco': {u'mode': u'schedule',
#   u'mode_update_timestamp': 1481640199,
#   u'touched_by': 1},
#  u'eco_onboarding_needed': True,
#  u'emer_heat_delivery': u'forced-air',
#  u'emer_heat_enable': False,
#  u'emer_heat_source': u'electric',
#  u'equipment_type': u'electric',
#  u'error_code': u'',
#  u'fan_capabilities': u'stage1',
#  u'fan_control_state': False,
#  u'fan_cooling_enabled': True,
#  u'fan_cooling_readiness': u'ready',
#  u'fan_cooling_state': False,
#  u'fan_current_speed': u'off',
#  u'fan_duty_cycle': 900,
#  u'fan_duty_end_time': 25200,
#  u'fan_duty_start_time': 0,
#  u'fan_heat_cool_speed': u'auto',
#  u'fan_mode': u'auto',
#  u'fan_schedule_speed': u'stage1',
#  u'fan_timer_duration': 1800,
#  u'fan_timer_speed': u'stage1',
#  u'fan_timer_timeout': 0,
#  u'farsight_screen': u'target_temp',
#  u'filter_changed_date': 1479168000,
#  u'filter_changed_set_date': 1478853676,
#  u'filter_reminder_enabled': True,
#  u'filter_reminder_level': 0,
#  u'forced_air': True,
#  u'gear_threshold_high': 0.0,
#  u'gear_threshold_low': 0.0,
#  u'has_air_filter': True,
#  u'has_alt_heat': False,
#  u'has_aux_heat': False,
#  u'has_dehumidifier': False,
#  u'has_dual_fuel': False,
#  u'has_emer_heat': False,
#  u'has_fan': True,
#  u'has_fossil_fuel': True,
#  u'has_heat_pump': False,
#  u'has_hot_water_control': False,
#  u'has_hot_water_temperature': False,
#  u'has_humidifier': False,
#  u'has_x2_alt_heat': False,
#  u'has_x2_cool': False,
#  u'has_x2_heat': False,
#  u'has_x3_cool': False,
#  u'has_x3_heat': False,
#  u'heat_link_connection': 0,
#  u'heat_pump_aux_threshold': 10.0,
#  u'heat_pump_aux_threshold_enabled': True,
#  u'heat_pump_comp_threshold': -31.5,
#  u'heat_pump_comp_threshold_enabled': False,
#  u'heat_x2_delivery': u'forced-air',
#  u'heat_x2_source': u'gas',
#  u'heat_x3_delivery': u'forced-air',
#  u'heat_x3_source': u'gas',
#  u'heater_delivery': u'forced-air',
#  u'heater_source': u'gas',
#  u'heatpump_ready': False,
#  u'heatpump_savings': u'off',
#  u'heatpump_setback_active': False,
#  u'home_away_input': True,
#  u'hot_water_active': False,
#  u'hot_water_away_active': False,
#  u'hot_water_away_enabled': True,
#  u'hot_water_boiling_state': True,
#  u'humidifier_state': False,
#  u'humidifier_type': u'unknown',
#  u'humidity_control_lockout_enabled': False,
#  u'humidity_control_lockout_end_time': 0,
#  u'humidity_control_lockout_start_time': 0,
#  u'hvac_pins': u'W1,Y1,Rh,G',
#  u'hvac_safety_shutoff_active': False,
#  u'hvac_smoke_safety_shutoff_active': False,
#  u'hvac_staging_ignore': False,
#  u'hvac_wires': u'Heat,Cool,Fan,Rh',
#  u'is_furnace_shutdown': False,
#  u'last_software_update_utc_secs': 1477962549,
#  u'leaf': False,
#  u'leaf_away_high': 28.87999,
#  u'leaf_away_low': 20.08333,
#  u'leaf_schedule_delta': 1.10999,
#  u'leaf_threshold_cool': 0.0,
#  u'leaf_threshold_heat': 22.23,
#  u'learning_days_completed_cool': 105,
#  u'learning_days_completed_heat': 122,
#  u'learning_days_completed_range': 72,
#  u'learning_mode': True,
#  u'learning_state': u'slow',
#  u'learning_time': 22,
#  u'local_ip': u'10.0.0.106',
#  u'logging_priority': u'informational',
#  u'lower_safety_temp': 7.22221,
#  u'lower_safety_temp_enabled': True,
#  u'mac_address': u'18b43071fa3a',
#  u'maint_band_lower': 0.39,
#  u'maint_band_upper': 0.39,
#  u'max_nighttime_preconditioning_seconds': 18000,
#  u'model_version': u'Display-3.4',
#  u'nlclient_state': u'',
#  u'note_codes': [],
#  u'ob_orientation': u'O',
#  u'ob_persistence': True,
#  u'oob_interview_completed': True,
#  u'oob_startup_completed': True,
#  u'oob_summary_completed': True,
#  u'oob_temp_completed': True,
#  u'oob_test_completed': True,
#  u'oob_where_completed': True,
#  u'oob_wifi_completed': True,
#  u'oob_wires_completed': True,
#  u'pin_c_description': u'none',
#  u'pin_g_description': u'fan',
#  u'pin_ob_description': u'none',
#  u'pin_rc_description': u'none',
#  u'pin_rh_description': u'power',
#  u'pin_star_description': u'none',
#  u'pin_w1_description': u'heat',
#  u'pin_w2aux_description': u'none',
#  u'pin_y1_description': u'cool',
#  u'pin_y2_description': u'none',
#  u'postal_code': u'43615',
#  u'preconditioning_active': False,
#  u'preconditioning_enabled': True,
#  u'preconditioning_ready': True,
#  u'pro_id': u'HP8A8A',
#  u'radiant_control_enabled': False,
#  u'range_enable': True,
#  u'rssi': 73.0,
#  u'safety_state': u'none',
#  u'safety_state_time': 1479600550,
#  u'safety_temp_activating_hvac': False,
#  u'schedule_learning_reset': False,
#  u'schedules': [],
#  u'serial_number': u'09AA01AC46150F2G',
#  u'should_wake_on_approach': True,
#  u'smoke_shutoff_supported': True,
#  u'star_type': u'unknown',
#  u'sunlight_correction_active': False,
#  u'sunlight_correction_enabled': False,
#  u'sunlight_correction_ready': False,
#  u'switch_system_off': False,
#  u'target_humidity': 35.0,
#  u'target_humidity_enabled': False,
#  u'target_time_confidence': 0.0,
#  u'temperature_lock': False,
#  u'temperature_lock_high_temp': 22.222,
#  u'temperature_lock_low_temp': 20.0,
#  u'temperature_lock_pin_hash': u'',
#  u'temperature_scale': u'F',
#  u'time_to_target': 0,
#  u'time_to_target_training': u'ready',
#  u'tou_icon': False,
#  u'touched_by': {},
#  u'type': u'TBD',
#  u'upper_safety_temp': 35.062,
#  u'upper_safety_temp_enabled': True,
#  u'user_brightness': u'auto',
#  u'where_id': u'00000000-0000-0000-0000-00010000000c',
#  u'y2_type': u'unknown'}

# %%
len(x)
# Out:
# 208

# %%
for item in x:
    print item, type(x[str(item)]),","
# Out:
# heat_pump_comp_threshold <type 'float'> ,
# leaf_away_high <type 'float'> ,
# schedules <type 'list'> ,
# tou_icon <type 'bool'> ,
# max_nighttime_preconditioning_seconds <type 'int'> ,
# oob_temp_completed <type 'bool'> ,
# postal_code <type 'unicode'> ,
# heater_delivery <type 'unicode'> ,
# country_code <type 'unicode'> ,
# star_type <type 'unicode'> ,
# heat_x3_source <type 'unicode'> ,
# fan_timer_duration <type 'int'> ,
# backplate_serial_number <type 'unicode'> ,
# hvac_wires <type 'unicode'> ,
# humidifier_type <type 'unicode'> ,
# sunlight_correction_active <type 'bool'> ,
# backplate_bsl_info <type 'unicode'> ,
# temperature_lock <type 'bool'> ,
# auto_away_reset <type 'bool'> ,
# dual_fuel_breakpoint_override <type 'unicode'> ,
# has_x3_heat <type 'bool'> ,
# oob_wifi_completed <type 'bool'> ,
# alt_heat_x2_delivery <type 'unicode'> ,
# oob_startup_completed <type 'bool'> ,
# maint_band_lower <type 'float'> ,
# device_locale <type 'unicode'> ,
# learning_time <type 'int'> ,
# should_wake_on_approach <type 'bool'> ,
# gear_threshold_low <type 'float'> ,
# has_fan <type 'bool'> ,
# auto_dehum_state <type 'bool'> ,
# lower_safety_temp_enabled <type 'bool'> ,
# backplate_model <type 'unicode'> ,
# heat_x2_source <type 'unicode'> ,
# aux_heat_source <type 'unicode'> ,
# filter_changed_date <type 'int'> ,
# last_software_update_utc_secs <type 'int'> ,
# equipment_type <type 'unicode'> ,
# heat_pump_comp_threshold_enabled <type 'bool'> ,
# dehumidifier_orientation_selected <type 'unicode'> ,
# forced_air <type 'bool'> ,
# cooling_x3_delivery <type 'unicode'> ,
# aux_lockout_leaf <type 'float'> ,
# away_temperature_high_adjusted <type 'float'> ,
# filter_reminder_level <type 'int'> ,
# humidifier_state <type 'bool'> ,
# error_code <type 'unicode'> ,
# learning_mode <type 'bool'> ,
# has_x2_cool <type 'bool'> ,
# hot_water_away_enabled <type 'bool'> ,
# hvac_pins <type 'unicode'> ,
# preconditioning_ready <type 'bool'> ,
# eco_onboarding_needed <type 'bool'> ,
# switch_system_off <type 'bool'> ,
# creation_time <type 'int'> ,
# serial_number <type 'unicode'> ,
# pin_star_description <type 'unicode'> ,
# has_aux_heat <type 'bool'> ,
# learning_days_completed_cool <type 'int'> ,
# away_temperature_low_enabled <type 'bool'> ,
# home_away_input <type 'bool'> ,
# note_codes <type 'list'> ,
# leaf_threshold_heat <type 'float'> ,
# y2_type <type 'unicode'> ,
# auto_dehum_enabled <type 'bool'> ,
# temperature_scale <type 'unicode'> ,
# time_to_target <type 'int'> ,
# alt_heat_x2_source <type 'unicode'> ,
# has_humidifier <type 'bool'> ,
# gear_threshold_high <type 'float'> ,
# current_schedule_mode <type 'unicode'> ,
# logging_priority <type 'unicode'> ,
# fan_timer_speed <type 'unicode'> ,
# fan_cooling_readiness <type 'unicode'> ,
# safety_state <type 'unicode'> ,
# battery_level <type 'float'> ,
# humidity_control_lockout_end_time <type 'int'> ,
# eco <type 'dict'> ,
# ob_persistence <type 'bool'> ,
# hvac_safety_shutoff_active <type 'bool'> ,
# schedule_learning_reset <type 'bool'> ,
# pin_y2_description <type 'unicode'> ,
# emer_heat_source <type 'unicode'> ,
# filter_reminder_enabled <type 'bool'> ,
# rssi <type 'float'> ,
# $version <type 'int'> ,
# leaf_away_low <type 'float'> ,
# filter_changed_set_date <type 'int'> ,
# aux_heat_delivery <type 'unicode'> ,
# smoke_shutoff_supported <type 'bool'> ,
# away_temperature_high <type 'float'> ,
# fan_duty_start_time <type 'int'> ,
# target_humidity_enabled <type 'bool'> ,
# pin_rh_description <type 'unicode'> ,
# leaf_threshold_cool <type 'float'> ,
# sunlight_correction_ready <type 'bool'> ,
# fan_timer_timeout <type 'int'> ,
# has_hot_water_control <type 'bool'> ,
# farsight_screen <type 'unicode'> ,
# safety_temp_activating_hvac <type 'bool'> ,
# has_dual_fuel <type 'bool'> ,
# cooling_x3_source <type 'unicode'> ,
# heatpump_setback_active <type 'bool'> ,
# compressor_lockout_leaf <type 'float'> ,
# has_heat_pump <type 'bool'> ,
# fan_control_state <type 'bool'> ,
# model_version <type 'unicode'> ,
# oob_test_completed <type 'bool'> ,
# sunlight_correction_enabled <type 'bool'> ,
# current_version <type 'unicode'> ,
# away_temperature_high_enabled <type 'bool'> ,
# alt_heat_delivery <type 'unicode'> ,
# current_humidity <type 'int'> ,
# target_humidity <type 'float'> ,
# where_id <type 'unicode'> ,
# backplate_mono_version <type 'unicode'> ,
# has_fossil_fuel <type 'bool'> ,
# mac_address <type 'unicode'> ,
# temperature_lock_low_temp <type 'float'> ,
# has_hot_water_temperature <type 'bool'> ,
# type <type 'unicode'> ,
# lower_safety_temp <type 'float'> ,
# preconditioning_active <type 'bool'> ,
# hvac_smoke_safety_shutoff_active <type 'bool'> ,
# humidity_control_lockout_start_time <type 'int'> ,
# pin_g_description <type 'unicode'> ,
# oob_wires_completed <type 'bool'> ,
# fan_mode <type 'unicode'> ,
# fan_current_speed <type 'unicode'> ,
# fan_cooling_enabled <type 'bool'> ,
# range_enable <type 'bool'> ,
# heatpump_savings <type 'unicode'> ,
# radiant_control_enabled <type 'bool'> ,
# cooling_source <type 'unicode'> ,
# pin_ob_description <type 'unicode'> ,
# hvac_staging_ignore <type 'bool'> ,
# humidity_control_lockout_enabled <type 'bool'> ,
# fan_duty_cycle <type 'int'> ,
# heatpump_ready <type 'bool'> ,
# preconditioning_enabled <type 'bool'> ,
# oob_interview_completed <type 'bool'> ,
# target_time_confidence <type 'float'> ,
# click_sound <type 'unicode'> ,
# cooling_x2_delivery <type 'unicode'> ,
# pin_w1_description <type 'unicode'> ,
# oob_summary_completed <type 'bool'> ,
# has_air_filter <type 'bool'> ,
# cooling_x2_source <type 'unicode'> ,
# temperature_lock_high_temp <type 'float'> ,
# heat_pump_aux_threshold <type 'float'> ,
# learning_days_completed_range <type 'int'> ,
# fan_schedule_speed <type 'unicode'> ,
# has_emer_heat <type 'bool'> ,
# has_alt_heat <type 'bool'> ,
# leaf_schedule_delta <type 'float'> ,
# backplate_bsl_version <type 'unicode'> ,
# user_brightness <type 'unicode'> ,
# upper_safety_temp <type 'float'> ,
# pin_w2aux_description <type 'unicode'> ,
# pin_rc_description <type 'unicode'> ,
# pro_id <type 'unicode'> ,
# has_dehumidifier <type 'bool'> ,
# maint_band_upper <type 'float'> ,
# hot_water_boiling_state <type 'bool'> ,
# emer_heat_delivery <type 'unicode'> ,
# pin_y1_description <type 'unicode'> ,
# capability_level <type 'float'> ,
# away_temperature_low_adjusted <type 'float'> ,
# available_locales <type 'unicode'> ,
# dehumidifier_state <type 'bool'> ,
# safety_state_time <type 'int'> ,
# dehumidifier_type <type 'unicode'> ,
# demand_charge_icon <type 'bool'> ,
# nlclient_state <type 'unicode'> ,
# upper_safety_temp_enabled <type 'bool'> ,
# learning_state <type 'unicode'> ,
# time_to_target_training <type 'unicode'> ,
# fan_cooling_state <type 'bool'> ,
# fan_duty_end_time <type 'int'> ,
# alt_heat_source <type 'unicode'> ,
# $timestamp <type 'int'> ,
# heat_link_connection <type 'int'> ,
# temperature_lock_pin_hash <type 'unicode'> ,
# cooling_delivery <type 'unicode'> ,
# heat_pump_aux_threshold_enabled <type 'bool'> ,
# fan_heat_cool_speed <type 'unicode'> ,
# hot_water_active <type 'bool'> ,
# heat_x3_delivery <type 'unicode'> ,
# ob_orientation <type 'unicode'> ,
# touched_by <type 'dict'> ,
# leaf <type 'bool'> ,
# emer_heat_enable <type 'bool'> ,
# backplate_mono_info <type 'unicode'> ,
# auto_away_enable <type 'bool'> ,
# fan_capabilities <type 'unicode'> ,
# hot_water_away_active <type 'bool'> ,
# has_x3_cool <type 'bool'> ,
# local_ip <type 'unicode'> ,
# has_x2_heat <type 'bool'> ,
# away_temperature_low <type 'float'> ,
# oob_where_completed <type 'bool'> ,
# heat_x2_delivery <type 'unicode'> ,
# learning_days_completed_heat <type 'int'> ,
# is_furnace_shutdown <type 'bool'> ,
# dual_fuel_breakpoint <type 'float'> ,
# heater_source <type 'unicode'> ,
# pin_c_description <type 'unicode'> ,
# has_x2_alt_heat <type 'bool'> ,
