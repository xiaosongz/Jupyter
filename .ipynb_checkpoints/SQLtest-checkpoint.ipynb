# %% [markdown]
# Successfully connected to mysql server

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# The following commands are need for the buggy mysqldb's python3 support

# %%
try:
    import pymysql
    pymysql.install_as_MySQLdb()
    print('success')
except ImportError:
    pass
# Out:
# success

# %%
# %sql mysql://root:k14I12d`@localhost/test
# Out:
# 'Connected: root@test'

# %%
# %%sql
# USE test;
# SHOW TABLES;
# Out:
# 0 rows affected.
# 1 rows affected.
# [('user_key',)]

# %%
# %%sql
# DESCRIBE user_key;
# Out:
# 1 rows affected.
# [('key', 'varchar(50)', 'NO', '', None, '')]

# %%
# %%sql
# SELECT * FROM user_key;
# Out:
# 200 rows affected.
# [('nIaJUiYvSRX6CWqYGs7N',),
#  ('utFjiRBtI78nymF4luFr',),
#  ('lQyDuEpS4JdLv3yBpcpK',),
#  ('SaGq8eQGQuidZMPbdfEM',),
#  ('eUFrL4xECpv9y3EmA8i9',),
#  ('8OCiYiCay7p8X0YtlpQd',),
#  ('6rGn7TiDznKFEDKg4Krt',),
#  ('WddACPZWymTzLOPBEKE7',),
#  ('oLHVPX8BrRBexzQZxQAA',),
#  ('lh8DDKP0wdccgMGdmcWA',),
#  ('4nfEbcbkjrZBIwF3Bfsf',),
#  ('jP6kqi5xbWAZTqdCeeAX',),
#  ('YTCZeO8DOyk5EDkv61zo',),
#  ('kaPFnJRP7tbUvLdmJ4L6',),
#  ('r4XPELUolDuJW81MZKeT',),
#  ('8PoJNPBfjobEdZDfIwFt',),
#  ('3JPS78kmRtyg4AimQJIE',),
#  ('uiSvVN2z87qbNcUzsNSy',),
#  ('UOGV82BKMlTGDjwcqvil',),
#  ('u797dI1DhECilsjftaXY',),
#  ('RK9TMNdzKdXLCinPlBnY',),
#  ('It9x6gU5ejSh2GNBxFR7',),
#  ('Fa7pPmtjhhUjjJPaVTaC',),
#  ('vL4lv8TTXLei4XMm4qyY',),
#  ('5E7mqvcdTb0YESkzzNIp',),
#  ('pY7gA4cYvfh0bpIWb9rA',),
#  ('SpnVKswRl1OZfA7kvuz9',),
#  ('GtUVDUKCUMsYeU35P9cq',),
#  ('2KHvAVoCQLU1gh8GDGjn',),
#  ('d0gpmKG05o3fduo8V1SP',),
#  ('faoRj0DozAusKFQIW57e',),
#  ('trFnAwJeeS8LF0FFNyDn',),
# ...

# %%
# %%sql
# CREATE DATABASE NEST;
# Out:
# 1 rows affected.
# []

# %%
# %%sql
# USE NEST;
# Out:
# 0 rows affected.
# []

# %%
# %%sql
# CREATE TABLE device;
# Out:
# (pymysql.err.ProgrammingError) (1113, 'A table must have at least 1 column') [SQL: 'CREATE TABLE device;']

# %%
di = {u'$timestamp': 1481648378169,
 u'$version': -7418,
 u'alt_heat_delivery': u'forced-air',
 u'alt_heat_source': u'gas',
 u'alt_heat_x2_delivery': u'forced-air',
 u'alt_heat_x2_source': u'gas',
 u'auto_away_enable': True,
 u'auto_away_reset': False,
 u'auto_dehum_enabled': True,
 u'auto_dehum_state': False,
 u'aux_heat_delivery': u'forced-air',
 u'aux_heat_source': u'electric',
 u'aux_lockout_leaf': 10.0,
 u'available_locales': u'en_US,fr_CA,es_US,en_GB,fr_FR,nl_NL',
 u'away_temperature_high': 30.278,
 u'away_temperature_high_adjusted': 30.278,
 u'away_temperature_high_enabled': True,
 u'away_temperature_low': 10.39597,
 u'away_temperature_low_adjusted': 10.39597,
 u'away_temperature_low_enabled': True,
 u'backplate_bsl_info': u'BSL',
 u'backplate_bsl_version': u'3.1',
 u'backplate_model': u'Backplate-5.3',
 u'backplate_mono_info': u'TFE (BP_D3) 1.2.9 (root@sticks.pao.corp.google.com) 2016-08-17 12:36:42',
 u'backplate_mono_version': u'1.2.9',
 u'backplate_serial_number': u'09DA01AC44150M4L',
 u'battery_level': 3.904,
 u'capability_level': 5.6,
 u'click_sound': u'on',
 u'compressor_lockout_leaf': -17.79999,
 u'cooling_delivery': u'unknown',
 u'cooling_source': u'electric',
 u'cooling_x2_delivery': u'unknown',
 u'cooling_x2_source': u'electric',
 u'cooling_x3_delivery': u'unknown',
 u'cooling_x3_source': u'electric',
 u'country_code': u'US',
 u'creation_time': 1452649087971,
 u'current_humidity': 34,
 u'current_schedule_mode': u'HEAT',
 u'current_version': u'5.6-7',
 u'dehumidifier_orientation_selected': u'unknown',
 u'dehumidifier_state': False,
 u'dehumidifier_type': u'unknown',
 u'demand_charge_icon': False,
 u'device_locale': u'en_US',
 u'dual_fuel_breakpoint': -1.0,
 u'dual_fuel_breakpoint_override': u'none',
 u'eco': {u'mode': u'schedule',
  u'mode_update_timestamp': 1481640199,
  u'touched_by': 1},
 u'eco_onboarding_needed': True,
 u'emer_heat_delivery': u'forced-air',
 u'emer_heat_enable': False,
 u'emer_heat_source': u'electric',
 u'equipment_type': u'electric',
 u'error_code': u'',
 u'fan_capabilities': u'stage1',
 u'fan_control_state': False,
 u'fan_cooling_enabled': True,
 u'fan_cooling_readiness': u'ready',
 u'fan_cooling_state': False,
 u'fan_current_speed': u'off',
 u'fan_duty_cycle': 900,
 u'fan_duty_end_time': 25200,
 u'fan_duty_start_time': 0,
 u'fan_heat_cool_speed': u'auto',
 u'fan_mode': u'auto',
 u'fan_schedule_speed': u'stage1',
 u'fan_timer_duration': 1800,
 u'fan_timer_speed': u'stage1',
 u'fan_timer_timeout': 0,
 u'farsight_screen': u'target_temp',
 u'filter_changed_date': 1479168000,
 u'filter_changed_set_date': 1478853676,
 u'filter_reminder_enabled': True,
 u'filter_reminder_level': 0,
 u'forced_air': True,
 u'gear_threshold_high': 0.0,
 u'gear_threshold_low': 0.0,
 u'has_air_filter': True,
 u'has_alt_heat': False,
 u'has_aux_heat': False,
 u'has_dehumidifier': False,
 u'has_dual_fuel': False,
 u'has_emer_heat': False,
 u'has_fan': True,
 u'has_fossil_fuel': True,
 u'has_heat_pump': False,
 u'has_hot_water_control': False,
 u'has_hot_water_temperature': False,
 u'has_humidifier': False,
 u'has_x2_alt_heat': False,
 u'has_x2_cool': False,
 u'has_x2_heat': False,
 u'has_x3_cool': False,
 u'has_x3_heat': False,
 u'heat_link_connection': 0,
 u'heat_pump_aux_threshold': 10.0,
 u'heat_pump_aux_threshold_enabled': True,
 u'heat_pump_comp_threshold': -31.5,
 u'heat_pump_comp_threshold_enabled': False,
 u'heat_x2_delivery': u'forced-air',
 u'heat_x2_source': u'gas',
 u'heat_x3_delivery': u'forced-air',
 u'heat_x3_source': u'gas',
 u'heater_delivery': u'forced-air',
 u'heater_source': u'gas',
 u'heatpump_ready': False,
 u'heatpump_savings': u'off',
 u'heatpump_setback_active': False,
 u'home_away_input': True,
 u'hot_water_active': False,
 u'hot_water_away_active': False,
 u'hot_water_away_enabled': True,
 u'hot_water_boiling_state': True,
 u'humidifier_state': False,
 u'humidifier_type': u'unknown',
 u'humidity_control_lockout_enabled': False,
 u'humidity_control_lockout_end_time': 0,
 u'humidity_control_lockout_start_time': 0,
 u'hvac_pins': u'W1,Y1,Rh,G',
 u'hvac_safety_shutoff_active': False,
 u'hvac_smoke_safety_shutoff_active': False,
 u'hvac_staging_ignore': False,
 u'hvac_wires': u'Heat,Cool,Fan,Rh',
 u'is_furnace_shutdown': False,
 u'last_software_update_utc_secs': 1477962549,
 u'leaf': False,
 u'leaf_away_high': 28.87999,
 u'leaf_away_low': 20.08333,
 u'leaf_schedule_delta': 1.10999,
 u'leaf_threshold_cool': 0.0,
 u'leaf_threshold_heat': 22.23,
 u'learning_days_completed_cool': 105,
 u'learning_days_completed_heat': 122,
 u'learning_days_completed_range': 72,
 u'learning_mode': True,
 u'learning_state': u'slow',
 u'learning_time': 22,
 u'local_ip': u'10.0.0.106',
 u'logging_priority': u'informational',
 u'lower_safety_temp': 7.22221,
 u'lower_safety_temp_enabled': True,
 u'mac_address': u'18b43071fa3a',
 u'maint_band_lower': 0.39,
 u'maint_band_upper': 0.39,
 u'max_nighttime_preconditioning_seconds': 18000,
 u'model_version': u'Display-3.4',
 u'nlclient_state': u'',
 u'note_codes': [],
 u'ob_orientation': u'O',
 u'ob_persistence': True,
 u'oob_interview_completed': True,
 u'oob_startup_completed': True,
 u'oob_summary_completed': True,
 u'oob_temp_completed': True,
 u'oob_test_completed': True,
 u'oob_where_completed': True,
 u'oob_wifi_completed': True,
 u'oob_wires_completed': True,
 u'pin_c_description': u'none',
 u'pin_g_description': u'fan',
 u'pin_ob_description': u'none',
 u'pin_rc_description': u'none',
 u'pin_rh_description': u'power',
 u'pin_star_description': u'none',
 u'pin_w1_description': u'heat',
 u'pin_w2aux_description': u'none',
 u'pin_y1_description': u'cool',
 u'pin_y2_description': u'none',
 u'postal_code': u'43615',
 u'preconditioning_active': False,
 u'preconditioning_enabled': True,
 u'preconditioning_ready': True,
 u'pro_id': u'HP8A8A',
 u'radiant_control_enabled': False,
 u'range_enable': True,
 u'rssi': 73.0,
 u'safety_state': u'none',
 u'safety_state_time': 1479600550,
 u'safety_temp_activating_hvac': False,
 u'schedule_learning_reset': False,
 u'schedules': [],
 u'serial_number': u'09AA01AC46150F2G',
 u'should_wake_on_approach': True,
 u'smoke_shutoff_supported': True,
 u'star_type': u'unknown',
 u'sunlight_correction_active': False,
 u'sunlight_correction_enabled': False,
 u'sunlight_correction_ready': False,
 u'switch_system_off': False,
 u'target_humidity': 35.0,
 u'target_humidity_enabled': False,
 u'target_time_confidence': 0.0,
 u'temperature_lock': False,
 u'temperature_lock_high_temp': 22.222,
 u'temperature_lock_low_temp': 20.0,
 u'temperature_lock_pin_hash': u'',
 u'temperature_scale': u'F',
 u'time_to_target': 0,
 u'time_to_target_training': u'ready',
 u'tou_icon': False,
 u'touched_by': {},
 u'type': u'TBD',
 u'upper_safety_temp': 35.062,
 u'upper_safety_temp_enabled': True,
 u'user_brightness': u'auto',
 u'where_id': u'00000000-0000-0000-0000-00010000000c',
 u'y2_type': u'unknown'}

# %%
type(di)
# Out:
# dict

# %%
import MySQLdb
import string
import random

KEY_LEN = 20
KEY_ALL = 200


def base_str():
    return (string.letters + string.digits)


class mysql_init(object):

    def __init__(self, conn):
        self.conn = None

    # connect to mysql
    def connect(self):
        self.conn = MySQLdb.connect(
            host="localhost",
            port=3306,
            user="root",
            passwd="k14I12d`",
            db="test",
            charset="utf8"
        )
        print "success connect"

    def cursor(self):
        try:
            return self.conn.cursor()
        except (AttributeError, MySQLdb.OperationalError):
            self.connect()
            return self.conn.cursor()

    def commit(self):
        return self.conn.commit()

    def close(self):
        return self.conn.close()


def process():
    print 'po'
    dbconn.connect()
    conn = dbconn.cursor()
    InsertDatas(conn)
    QueryData(conn)
    dbconn.commit()
    dbconn.close()
    print 'done'

def execute(sql):
    '''执行sql'''
    print 'successfully excuete'
    conn=dbconn.cursor()
    conn.execute(sql)
    

def executemany(sql, tmp):
    '''插入多条数据'''
    conn=dbconn.cursor()
    conn.executemany(sql,tmp)


def query(sql, conn):
    '''查询sql'''
    # conn=dbconn.cursor()
    conn.execute(sql)
    rows = conn.fetchall()
    return rows


def DropTable(conn):
    conn=dbconn.cursor()
    conn.execute("DROP TABLE IF EXISTS `user_key`")


def CreateTable(conn):
    # conn=dbconn.cursor()
    print 'table created'
    sql_create = ''' CREATE TABLE `user_key` (`key` varchar(50) NOT NULL)'''
    conn.execute(sql_create)


def InsertDatas(conn):
    # conn=dbconn.cursor()
    # insert_sql = "insert into user_key values(%s)"
    insert_sql = "INSERT INTO user_key VALUES (%(value)s)"
    key_list = key_num(KEY_ALL)
    print len(key_list)
    # conn.executemany(insert_sql,str(key_listi))
    # conn.executemany("INSERT INTO user_key VALUES (%(value)s)",
    #                   [dict(value=v) for v in key_list])
    conn.executemany(insert_sql, [dict(value=v) for v in key_list])
    print 'key incerted'


def DeleteData():
    del_sql = "delete from user_key where id=2"
    execute(del_sql)


def QueryData(conn):
    sql = "select * from * limit 20"
    rows = query(sql, conn)
    printResult(rows)


def printResult(rows):
    i = 0
    if rows is None:
        print "rows None"
    for row in rows:
        i = i +1
        print i,row

if __name__ == "__main__":
    dbconn = mysql_init(None)
    process()
# Out:
# dict_keys(['has_heat_pump', 'heat_x3_delivery', 'learning_state', 'eco', 'available_locales', 'heater_delivery', 'away_temperature_high_enabled', 'has_x2_alt_heat', 'fan_timer_duration', 'humidity_control_lockout_enabled', 'fan_cooling_enabled', 'switch_system_off', 'temperature_lock_low_temp', 'humidity_control_lockout_end_time', 'backplate_bsl_info', 'pin_y2_description', 'maint_band_lower', 'sunlight_correction_ready', 'heat_x2_source', 'has_x2_cool', 'pin_y1_description', 'time_to_target_training', 'has_hot_water_control', 'cooling_delivery', 'hot_water_active', 'fan_duty_end_time', 'preconditioning_enabled', 'fan_capabilities', 'emer_heat_enable', '$version', 'upper_safety_temp', 'should_wake_on_approach', 'capability_level', 'leaf', 'heatpump_savings', 'serial_number', 'oob_interview_completed', 'type', 'user_brightness', 'has_humidifier', 'farsight_screen', 'tou_icon', 'preconditioning_ready', 'equipment_type', 'alt_heat_x2_source', 'has_air_filter', 'has_x2_heat', 'current_ve
# ...

# %%
# %%sql
# USE NEST;
# Out:
# 0 rows affected.
# []

# %%
# %sql SHOW TABLES;
# Out:
# 1 rows affected.
# [('test',)]

# %%
# %%sql ALERT TABLE test
# ADD COLUMN (temp INT);
# Out:
# (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'ALERT TABLE test \nADD COLUMN (temp INT)' at line 1") [SQL: 'ALERT TABLE test \nADD COLUMN (temp INT);']

# %%
# %%sql
# DESCRIBE test;
# Out:
# 1 rows affected.
# [('Timeget', 'timestamp', 'NO', '', 'CURRENT_TIMESTAMP', 'on update CURRENT_TIMESTAMP')]

# %%
# %%sql
# INCERT INTO test(temperature) VALUES (73);
# Out:
# (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'INCERT INTO test(temperature) VALUES (73)' at line 1") [SQL: 'INCERT INTO test(temperature) VALUES (73);']

# %%
# %%sql
#
# CREATE TABLE IF NOT EXISTS test1(
# leaf_away_high FLOAT ,
# schedules varchar );
# Out:
# (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near ')' at line 3") [SQL: 'CREATE TABLE IF NOT EXISTS test1(\nleaf_away_high FLOAT ,\nschedules varchar );']

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS Deviceifo(
# heat_pump_comp_threshold FLOAT ,
# leaf_away_high FLOAT ,
# schedules varchar ,
# tou_icon BOOLEAN,
# max_nighttime_preconditioning_seconds INTEGER ,
# oob_temp_completed BOOLEAN,
# postal_code varchar(255) ,
# heater_delivery varchar(255) ,
# country_code varchar(255) ,
# star_type varchar(255) ,
# heat_x3_source varchar(255) ,
# fan_timer_duration INTEGER ,
# backplate_serial_number varchar(255) ,
# hvac_wires varchar(255) ,
# humidifier_type varchar(255) ,
# sunlight_correction_active BOOLEAN,
# backplate_bsl_info varchar(255) ,
# temperature_lock BOOLEAN,
# auto_away_reset BOOLEAN,
# dual_fuel_breakpoint_override varchar(255) ,
# has_x3_heat BOOLEAN,
# oob_wifi_completed BOOLEAN,
# alt_heat_x2_delivery varchar(255) ,
# oob_startup_completed BOOLEAN,
# maint_band_lower FLOAT ,
# device_locale varchar(255) ,
# learning_time INTEGER ,
# should_wake_on_approach BOOLEAN,
# gear_threshold_low FLOAT ,
# has_fan BOOLEAN,
# auto_dehum_state BOOLEAN,
# lower_safety_temp_enabled BOOLEAN,
# backplate_model varchar(255) ,
# heat_x2_source varchar(255) ,
# aux_heat_source varchar(255) ,
# filter_changed_date INTEGER ,
# last_software_update_utc_secs INTEGER ,
# equipment_type varchar(255) ,
# heat_pump_comp_threshold_enabled BOOLEAN,
# dehumidifier_orientation_selected varchar(255) ,
# forced_air BOOLEAN,
# cooling_x3_delivery varchar(255) ,
# aux_lockout_leaf FLOAT ,
# away_temperature_high_adjusted FLOAT ,
# filter_reminder_level INTEGER ,
# humidifier_state BOOLEAN,
# error_code varchar(255) ,
# learning_mode BOOLEAN,
# has_x2_cool BOOLEAN,
# hot_water_away_enabled BOOLEAN,
# hvac_pins varchar(255) ,
# preconditioning_ready BOOLEAN,
# eco_onboarding_needed BOOLEAN,
# switch_system_off BOOLEAN,
# creation_time INTEGER ,
# serial_number varchar(255) ,
# pin_star_description varchar(255) ,
# has_aux_heat BOOLEAN,
# learning_days_completed_cool INTEGER ,
# away_temperature_low_enabled BOOLEAN,
# home_away_input BOOLEAN,
# note_codes varchar ,
# leaf_threshold_heat FLOAT ,
# y2_type varchar(255) ,
# auto_dehum_enabled BOOLEAN,
# temperature_scale varchar(255) ,
# time_to_target INTEGER ,
# alt_heat_x2_source varchar(255) ,
# has_humidifier BOOLEAN,
# gear_threshold_high FLOAT ,
# current_schedule_mode varchar(255) ,
# logging_priority varchar(255) ,
# fan_timer_speed varchar(255) ,
# fan_cooling_readiness varchar(255) ,
# safety_state varchar(255) ,
# battery_level FLOAT ,
# humidity_control_lockout_end_time INTEGER ,
# eco varchar ,
# ob_persistence BOOLEAN,
# hvac_safety_shutoff_active BOOLEAN,
# schedule_learning_reset BOOLEAN,
# pin_y2_description varchar(255) ,
# emer_heat_source varchar(255) ,
# filter_reminder_enabled BOOLEAN,
# rssi FLOAT ,
# $version INTEGER ,
# leaf_away_low FLOAT ,
# filter_changed_set_date INTEGER ,
# aux_heat_delivery varchar(255) ,
# smoke_shutoff_supported BOOLEAN,
# away_temperature_high FLOAT ,
# fan_duty_start_time INTEGER ,
# target_humidity_enabled BOOLEAN,
# pin_rh_description varchar(255) ,
# leaf_threshold_cool FLOAT ,
# sunlight_correction_ready BOOLEAN,
# fan_timer_timeout INTEGER ,
# has_hot_water_control BOOLEAN,
# farsight_screen varchar(255) ,
# safety_temp_activating_hvac BOOLEAN,
# has_dual_fuel BOOLEAN,
# cooling_x3_source varchar(255) ,
# heatpump_setback_active BOOLEAN,
# compressor_lockout_leaf FLOAT ,
# has_heat_pump BOOLEAN,
# fan_control_state BOOLEAN,
# model_version varchar(255) ,
# oob_test_completed BOOLEAN,
# sunlight_correction_enabled BOOLEAN,
# current_version varchar(255) ,
# away_temperature_high_enabled BOOLEAN,
# alt_heat_delivery varchar(255) ,
# current_humidity INTEGER ,
# target_humidity FLOAT ,
# where_id varchar(255) ,
# backplate_mono_version varchar(255) ,
# has_fossil_fuel BOOLEAN,
# mac_address varchar(255) ,
# temperature_lock_low_temp FLOAT ,
# has_hot_water_temperature BOOLEAN,
# type varchar(255) ,
# lower_safety_temp FLOAT ,
# preconditioning_active BOOLEAN,
# hvac_smoke_safety_shutoff_active BOOLEAN,
# humidity_control_lockout_start_time INTEGER ,
# pin_g_description varchar(255) ,
# oob_wires_completed BOOLEAN,
# fan_mode varchar(255) ,
# fan_current_speed varchar(255) ,
# fan_cooling_enabled BOOLEAN,
# range_enable BOOLEAN,
# heatpump_savings varchar(255) ,
# radiant_control_enabled BOOLEAN,
# cooling_source varchar(255) ,
# pin_ob_description varchar(255) ,
# hvac_staging_ignore BOOLEAN,
# humidity_control_lockout_enabled BOOLEAN,
# fan_duty_cycle INTEGER ,
# heatpump_ready BOOLEAN,
# preconditioning_enabled BOOLEAN,
# oob_interview_completed BOOLEAN,
# target_time_confidence FLOAT ,
# click_sound varchar(255) ,
# cooling_x2_delivery varchar(255) ,
# pin_w1_description varchar(255) ,
# oob_summary_completed BOOLEAN,
# has_air_filter BOOLEAN,
# cooling_x2_source varchar(255) ,
# temperature_lock_high_temp FLOAT ,
# heat_pump_aux_threshold FLOAT ,
# learning_days_completed_range INTEGER ,
# fan_schedule_speed varchar(255) ,
# has_emer_heat BOOLEAN,
# has_alt_heat BOOLEAN,
# leaf_schedule_delta FLOAT ,
# backplate_bsl_version varchar(255) ,
# user_brightness varchar(255) ,
# upper_safety_temp FLOAT ,
# pin_w2aux_description varchar(255) ,
# pin_rc_description varchar(255) ,
# pro_id varchar(255) ,
# has_dehumidifier BOOLEAN,
# maint_band_upper FLOAT ,
# hot_water_boiling_state BOOLEAN,
# emer_heat_delivery varchar(255) ,
# pin_y1_description varchar(255) ,
# capability_level FLOAT ,
# away_temperature_low_adjusted FLOAT ,
# available_locales varchar(255) ,
# dehumidifier_state BOOLEAN,
# safety_state_time INTEGER ,
# dehumidifier_type varchar(255) ,
# demand_charge_icon BOOLEAN,
# nlclient_state varchar(255) ,
# upper_safety_temp_enabled BOOLEAN,
# learning_state varchar(255) ,
# time_to_target_training varchar(255) ,
# fan_cooling_state BOOLEAN,
# fan_duty_end_time INTEGER ,
# alt_heat_source varchar(255) ,
# $timestamp INTEGER ,
# heat_link_connection INTEGER ,
# temperature_lock_pin_hash varchar(255) ,
# cooling_delivery varchar(255) ,
# heat_pump_aux_threshold_enabled BOOLEAN,
# fan_heat_cool_speed varchar(255) ,
# hot_water_active BOOLEAN,
# heat_x3_delivery varchar(255) ,
# ob_orientation varchar(255) ,
# touched_by varchar ,
# leaf BOOLEAN,
# emer_heat_enable BOOLEAN,
# backplate_mono_info varchar(255) ,
# auto_away_enable BOOLEAN,
# fan_capabilities varchar(255) ,
# hot_water_away_active BOOLEAN,
# has_x3_cool BOOLEAN,
# local_ip varchar(255) ,
# has_x2_heat BOOLEAN,
# away_temperature_low FLOAT ,
# oob_where_completed BOOLEAN,
# heat_x2_delivery varchar(255) ,
# learning_days_completed_heat INTEGER ,
# is_furnace_shutdown BOOLEAN,
# dual_fuel_breakpoint FLOAT ,
# heater_source varchar(255) ,
# pin_c_description varchar(255) ,
# has_x2_alt_heat BOOLEAN
# );
# Out:
# (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near '\ntou_icon BOOLEAN,\nmax_nighttime_preconditioning_seconds INTEGER ,\noob_temp_comp' at line 4") [SQL: 'CREATE TABLE IF NOT EXISTS Deviceifo(\nheat_pump_comp_threshold FLOAT ,\nleaf_away_high FLOAT ,\nschedules varchar ,\ntou_icon BOOLEAN,\nmax_nighttime_preconditioning_seconds INTEGER ,\noob_temp_completed BOOLEAN,\npostal_code varchar(255) ,\nheater_delivery varchar(255) ,\ncountry_code varchar(255) ,\nstar_type varchar(255) ,\nheat_x3_source varchar(255) ,\nfan_timer_duration INTEGER ,\nbackplate_serial_number varchar(255) ,\nhvac_wires varchar(255) ,\nhumidifier_type varchar(255) ,\nsunlight_correction_active BOOLEAN,\nbackplate_bsl_info varchar(255) ,\ntemperature_lock BOOLEAN,\nauto_away_reset BOOLEAN,\ndual_fuel_breakpoint_override varchar(255) ,\nhas_x3_heat BOOLEAN,\noob_wifi_completed BOOLEAN,\nalt_heat
# ...
